# %%
# !pip install PyDrive
# !pip install xlrd
# Out:
# Requirement already satisfied: PyDrive in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (1.6.7)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (4.1.2)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.11.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.11.3)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (3.4.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.4)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.2.2)
# Collecting xlrd
#   Downloading https://files.pythonhosted.org/packages/07/e6/e95c4eec6221bfd8528bcc4ea252a850bffcc4be88ebc367e23a1a84b0bb/xlrd-1.1.0-py2.py3-none-any.whl (108kB)
#     100% |████████████████████████████████| 112kB 4.2MB/s
# Installing collected packages: xlrd
# Successfully installed xlrd-1.1.0

# %%
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# !rm -rf structured.xlsx
download = drive.CreateFile({'id': '1oh_fic0-1N1xh4OlTvGMQ5BTKjOmUYKi'})
download.GetContentFile('structured.xlsx')

# %%
download3 = drive.CreateFile({'id': '1iFVW0RxqL1VNrIOrfJXrDkPHF8ewXH49'})
download3.GetContentFile('spark-2.3.1-bin-hadoop2.7.tgz')

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !tar xf spark-2.3.1-bin-hadoop2.7.tgz
# !pip install -q findspark

# %%
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.3.1-bin-hadoop2.7"

# %%
import pandas as pd
import numpy as np
import os
from time import time
from bs4 import BeautifulSoup
import math
starttime = time()

# %%
def conv(content):
    if(content != content):
        return np.NaN
    
    return str(content)

# %%
converters = {'Spam':conv, 'Body':conv, 'Subject':conv, 'From':conv, 'To':conv, 'X-UIDL':conv, 'Message-Id':conv, 'Sender':conv}

# %%
df_final = pd.read_excel('structured.xlsx', sheet_name='Sheet1', index_col=None, converters=converters )

# %%
# Feature1 -> From same as To. If yes -> 1, else 0
df_final['Feature1'] = 0
df_final.loc[df_final['From'] == df_final['To'], 'Feature1'] = 1
df_final['Feature1'].describe()
# Out:
# count    5039.000000
# mean        0.002183
# std         0.046676
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Feature1, dtype: float64

# %%
import re
def isValidEmailFormat(emails):
    for email in str(emails).split(','):
        if(email.isspace() or len(email) == 0):
            continue
            
        email = re.sub(r'(\n+)', r' ', str(email)).strip()
        print(email)
        
        if(re.match(r"(.+)<(.+)>|<(.+)>", email)):
            email = email[email.find("<")+1:-1]
            print(0, email)
            
        if(len(email) > 7):
            if(re.match("^.+@([?)[a-zA-Z0-9-.]+.([a-zA-Z]{2,3}|[0-9]{1,3})(]?))$", email) != None):
                print('continue')
                continue
            else:
                print('1')
                return 1
        else:
            return 1
        
    return 0

# %%
s1 = "<baileyl@cream.cambridge.scr.slb.com>, baileyl@delphi.com, baileyl@erols.com,"
print(s1)
isValidEmailFormat(s1)
# Out:
# <baileyl@cream.cambridge.scr.slb.com>, baileyl@delphi.com, baileyl@erols.com,
# <baileyl@cream.cambridge.scr.slb.com>
# 0 baileyl@cream.cambridge.scr.slb.com
# continue
# baileyl@delphi.com
# continue
# baileyl@erols.com
# continue
# 0

# %%
# Feature2 -> is the To column na or invalid ? 1->invalid, 0->valid
df_final['Feature2'] = 0
df_final['Feature2'] = df_final['To'].map(isValidEmailFormat)
df_final.loc[df_final['To'].isna(),'Feature2'] = 1
df_final[df_final['Feature2'] == 1][['Feature2','To']]
# Out:
# usr999@aol.com
# continue
# you@yourdomain.net
# continue
# carlovers@america.com
# continue
# linux-kernel@vger.rutgers.edu
# continue
# bguenter@gemprint.com       Is your site listed with the top search engines?  ListMe will       list you with 50 search engines and indexes for $90.       Satisfaction guaranteed!  Search engines are the only way most people have to find internet sites. But if your site is not listed
# 1
# bguenter@gemprint.com
# continue
# <bagpipes@acadia.net>
# 0 bagpipes@acadia.net
# continue
# user@aol.com
# continue
# bait@mikhail.qcc.sk.ca
# continue
# partner@mindlock.com
# continue
# bmail@bmail.com
# continue
# BeSeen@At.Our.Site.com
# continue
# easterbaskets@hotmail.com
# continue
# bmail@bmail.com
# continue
# healthNprosper@aol.com
# continue
# p40508@presence4u.com
# continue
# toto367.glossy.com@29086.com
# continue
# p40508@presence4u.com
# continue
# AmazingSecrets@WorldInner.Circle
# continue
# Shelley7247@juno.com
# continue
# CNC-L@UVVM.UVIC.CA
# continue
# wedeliver@hotmail.com
# continue
# tugei38@versant.de
# continue
# <badams@eastky.com>
# 0 badams@eastky.com
# continue
# UDog244@aol.com
# continue
# buratuss_ef@bigfoot.com
# continue
# Admin@WWW.QCC.SK.CA
# continue
# baileyl@cream.cambridge.scr.slb.com
# continue
# baileyl@delphi.com
# continue
# baileyl@erols.com
# continue
# nan
# bruceg@qcc.sk.ca
# continue
# bruce.guenter@gemprint.com       Is your site listed with the top search engines?  ListMe will       list you with 50 search engines and indexes for $90.       Satisfaction guaranteed!  Search engines are the only way most people have to find internet sites. But if your site is not listed
# 1
# dav1@fortune.com
# continue
# <vworlds@vworlds.com>
# 0 vworlds@vworlds.com
# continue
# <badmin@forum-de-beyrouth.com.lb>
# 0 badmin@forum-de-beyrouth.com.lb
# continue
# <vworlds@vworlds.com>
# 0 vworlds@vworlds.com
# continue
# members@your.net
# continue
# guluimai67@msn.com
# continue
# 1st2 Part 17 <looknow@pacbell.net>
# 0 looknow@pacbell.net
# continue
# bguenter@linus.vsource.com       Is your site listed with the top search engines?  ListMe will       list you with 50 search engines and indexes for $90.       Satisfaction guaranteed!  Search engines are the only way most people have to find internet sites. But if your site is not listed
# 1
# tridge@samba.org
# continue
# refinance@flax24.uwaterloo.ca
# continue
# <1@speedy.uwaterloo.ca>
# 0 1@speedy.uwaterloo.ca
# continue
# djakwwnKVYWTQBgnitpick@flax9.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# "'r-help@lists.R-project.org'" <r-help@stat.math.ethz.ch>
# 0 r-help@stat.math.ethz.ch
# continue
# Bert Freudenberg <bert@freudenbergs.de>
# 0 bert@freudenbergs.de
# continue
# nan
# the00@plg2.math.uwaterloo.ca
# continue
# debian-laptop@lists.debian.org
# continue
# samba-technical@lists.samba.org References: <20070515065119.0D86F162BD8@lists.samba.org>
# 0 20070515065119.0D86F162BD8@lists.samba.org
# continue
# simpsons@flax24.uwaterloo.ca
# continue
# elaastic@flax9.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# <reform@meerschwein.hh.schule.de>
# 0 reform@meerschwein.hh.schule.de
# continue
# <smiles@flax9.uwaterloo.ca>
# 0 smiles@flax9.uwaterloo.ca
# continue
# email1248@speedy.uwaterloo.ca
# continue
# Vaibhav Gathibandhe <gathibandhe.vaibhav@gmail.com>
# 0 gathibandhe.vaibhav@gmail.com
# continue
# r-help@stat.math.ethz.ch
# continue
# Faramarzi Monireh <monireh.faramarzi@env.ethz.ch> References: <0E92048BF87ADA4899A9E48A167124A401C8E65B@EX4.d.ethz.ch>
# 0 monireh.faramarzi@env.ethz.ch> References: <0E92048BF87ADA4899A9E48A167124A401C8E65B@EX4.d.ethz.ch
# continue
# <manager@flax9.uwaterloo.ca>
# 0 manager@flax9.uwaterloo.ca
# continue
# <smiles@flax9.uwaterloo.ca>
# 0 smiles@flax9.uwaterloo.ca
# continue
# elaastic@flax9.uwaterloo.ca
# continue
# ktwarwic@SPEEDY.UWATERLOO.CA
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# producttestpanel@flax9.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# gnitpick@speedy.uwaterloo.ca
# continue
# <the00@plg2.math.uwaterloo.ca>
# 0 the00@plg2.math.uwaterloo.ca
# continue
# speakup@braille.uwo.ca
# continue
# James Peach <jpeach@samba.org> References: <88CDDF0E-ACD7-4D02-A716-860FA5E70F38@samba.org> 	<4637F5E3.9060407@samba.org> 	<8D73A8A3-7D5E-45AD-B685-796D4CD249E1@samba.org>
# 0 jpeach@samba.org> References: <88CDDF0E-ACD7-4D02-A716-860FA5E70F38@samba.org> 	<4637F5E3.9060407@samba.org> 	<8D73A8A3-7D5E-45AD-B685-796D4CD249E1@samba.org
# continue
# <avcooper@flax9.uwaterloo.ca>
# 0 avcooper@flax9.uwaterloo.ca
# continue
# <1@speedy.uwaterloo.ca>
# 0 1@speedy.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# <opt2@flax9.uwaterloo.ca>
# 0 opt2@flax9.uwaterloo.ca
# continue
# Acm <the00@plg2.math.uwaterloo.ca>
# 0 the00@plg2.math.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# "Gerald (Jerry) Carter" <jerry@samba.org> References: <20070604104048.8504C162AF7@lists.samba.org> 	<46640C66.9070109@samba.org>
# 0 jerry@samba.org> References: <20070604104048.8504C162AF7@lists.samba.org> 	<46640C66.9070109@samba.org
# continue
# "Andrew Coopers" <avcooper@flax9.uwaterloo.ca>
# 0 avcooper@flax9.uwaterloo.ca
# continue
# "Andrew Coopers" <avcooper@flax9.uwaterloo.ca>
# 0 avcooper@flax9.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# perl6-language@perl.org
# continue
# <avcooper@flax9.uwaterloo.ca>
# 0 avcooper@flax9.uwaterloo.ca
# continue
# <ktwarwic@speedy.uwaterloo.ca>
# 0 ktwarwic@speedy.uwaterloo.ca
# continue
# "Netsearch" <netsearch@canola1.uwaterloo.ca>
# 0 netsearch@canola1.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# <ktwarwic@speedy.uwaterloo.ca>
# 0 ktwarwic@speedy.uwaterloo.ca
# continue
# R Help Mailing List <r-help@stat.math.ethz.ch>
# 0 r-help@stat.math.ethz.ch
# continue
# <adtrevors@plg.uwaterloo.ca>
# 0 adtrevors@plg.uwaterloo.ca
# continue
# "Speakup is a screen review system for Linux." <speakup@braille.uwo.ca>
# 0 speakup@braille.uwo.ca
# continue
# r-help@stat.math.ethz.ch
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# sugar@laptop.org
# continue
# email1563@speedy.uwaterloo.ca
# continue
# email523@speedy.uwaterloo.ca
# continue
# r-help@stat.math.ethz.ch
# continue
# the00@plg.uwaterloo.ca
# continue
# <the00@plg2.math.uwaterloo.ca>
# 0 the00@plg2.math.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# Theorize <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# General Copyright Discussions <discuss@list.digital-copyright.ca>
# 0 discuss@list.digital-copyright.ca
# continue
# <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# <mail@flax9.uwaterloo.ca>
# 0 mail@flax9.uwaterloo.ca
# continue
# <avcooper@flax9.uwaterloo.ca>
# 0 avcooper@flax9.uwaterloo.ca
# continue
# <manager@speedy.uwaterloo.ca>
# 0 manager@speedy.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# "OtherRecipients of perl Ticket #43325": ;
# 1
# smiles@speedy.uwaterloo.ca
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# tobias.verbeke@businessdecision.com References: <4684D039.2010302@uni-osnabrueck.de> 	<4684D6C1.4090300@businessdecision.com>
# 0 4684D039.2010302@uni-osnabrueck.de> 	<4684D6C1.4090300@businessdecision.com
# continue
# gnitpick@speedy.uwaterloo.ca
# continue
# Theorize <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# "Noftz Leslie" <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# <ktwarwic@flax9.uwaterloo.ca>
# 0 ktwarwic@flax9.uwaterloo.ca
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# <mail@flax9.uwaterloo.ca>
# 0 mail@flax9.uwaterloo.ca
# continue
# <the00@plg2.math.uwaterloo.ca>
# 0 the00@plg2.math.uwaterloo.ca
# continue
# mail@flax9.uwaterloo.ca
# continue
# ajmalton@plg2.math.uwaterloo.ca
# continue
# Captains <captains@flax24.uwaterloo.ca>
# 0 captains@flax24.uwaterloo.ca
# continue
# "R Help" <R-help@stat.math.ethz.ch>
# 0 R-help@stat.math.ethz.ch
# continue
# debian-legal@lists.debian.org
# continue
# <avcooper@speedy.uwaterloo.ca>
# 0 avcooper@speedy.uwaterloo.ca
# continue
# email1480@speedy.uwaterloo.ca
# continue
# ktwarwic@speedy.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# "Subscriber" <producttestpanel@flax9.uwaterloo.ca>
# 0 producttestpanel@flax9.uwaterloo.ca
# continue
# "smilesnn" <smilesnn@speedy.uwaterloo.ca>
# 0 smilesnn@speedy.uwaterloo.ca
# continue
# samba-technical@samba.org
# continue
# Acm <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# "Perl Beginners" <beginners@perl.org>
# 0 beginners@perl.org
# continue
# refinance@flax24.uwaterloo.ca
# continue
# "Annelle" <the00@plg2.math.uwaterloo.ca>
# 0 the00@plg2.math.uwaterloo.ca
# continue
# "eishbut@googlemail.com" <eishbut@googlemail.com>
# 0 eishbut@googlemail.com
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# simo <idra@samba.org> References: <20070418205000.88D4B1638B9@lists.samba.org>	<1176929909.16886.16.camel@localhost.localdomain>	<1176986243.23884.7.camel@localhost.localdomain>	<200704191330.l3JDUHaM092847@au.padl.com> 	<1176990812.23884.9.camel@localhost.localdomain>
# 0 idra@samba.org> References: <20070418205000.88D4B1638B9@lists.samba.org>	<1176929909.16886.16.camel@localhost.localdomain>	<1176986243.23884.7.camel@localhost.localdomain>	<200704191330.l3JDUHaM092847@au.padl.com> 	<1176990812.23884.9.camel@localhost.localdomain
# continue
# "Speakup is a screen review system for Linux." <speakup@braille.uwo.ca> Sent: Tuesday
# 0 speakup@braille.uwo.ca> Sent: Tuesda
# 1
# James Peach <jpeach@samba.org> References: <20070601183951.5E2FD162ADA@lists.samba.org> 	<6420B9F8-2699-49AD-812F-2D7C188DD2D5@samba.org>
# 0 jpeach@samba.org> References: <20070601183951.5E2FD162ADA@lists.samba.org> 	<6420B9F8-2699-49AD-812F-2D7C188DD2D5@samba.org
# continue
# <ktwarwic@flax9.uwaterloo.ca>
# 0 ktwarwic@flax9.uwaterloo.ca
# continue
# "Netsearch" <netsearch@canola1.uwaterloo.ca>
# 0 netsearch@canola1.uwaterloo.ca
# continue
# catchall@flax9.uwaterloo.ca
# continue
# <warwick@plg.uwaterloo.ca>
# 0 warwick@plg.uwaterloo.ca
# continue
# ktwarwic@flax9.UWATERLOO.CA
# continue
# producttestpanel@speedy.uwaterloo.ca
# continue
# Geetha <geethanw@iis.u-tokyo.ac.jp>
# 0 geethanw@iis.u-tokyo.ac.jp
# continue
# Mathew Snyder <theillien@yahoo.com>
# 0 theillien@yahoo.com
# continue
# samba-cvs@samba.org
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# sugar@lists.laptop.org
# continue
# smiles@flax9.uwaterloo.ca
# continue
# <gnitpick@speedy.uwaterloo.ca>
# 0 gnitpick@speedy.uwaterloo.ca
# continue
# R Help <R-help@stat.math.ethz.ch>
# 0 R-help@stat.math.ethz.ch
# continue
# bugs-bitbucket@netlabs.develooper.com
# continue
# mhln@mhlearningnetwork.com
# continue
# "Andrew Coopers" <avcooper@speedy.uwaterloo.ca>
# 0 avcooper@speedy.uwaterloo.ca
# continue
# captains@flax24.uwaterloo.ca
# continue
# gnitpick@speedy.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# producttestpanel@flax9.uwaterloo.ca
# continue
# Perl Beginners <beginners@perl.org>
# 0 beginners@perl.org
# continue
# <manager@flax9.uwaterloo.ca>
# 0 manager@flax9.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# "Subscriber" <cruiseca@flax9.uwaterloo.ca>
# 0 cruiseca@flax9.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# noreply@sourceforge.net
# continue
# R-help@stat.math.ethz.ch
# continue
# smiles@flax9.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# "Julien Barnier" <julien@no-log.org>
# 0 julien@no-log.org
# continue
# <r-help@stat.math.ethz.ch>
# 0 r-help@stat.math.ethz.ch
# continue
# smiles@speedy.uwaterloo.ca
# continue
# lendingtree@speedy.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# antelopehn@flax9.uwaterloo.ca
# continue
# catchall@flax9.uwaterloo.ca
# continue
# vcoopers@speedy.uwaterloo.ca
# continue
# Michael Poole <mdpoole@troilus.org>
# 0 mdpoole@troilus.org
# continue
# samba-cvs@samba.org
# continue
# cruiseca@speedy.uwaterloo.ca
# continue
# Mail <mail@flax9.uwaterloo.ca>
# 0 mail@flax9.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# <gnitpick@speedy.uwaterloo.ca>
# 0 gnitpick@speedy.uwaterloo.ca
# continue
# <the00@plg2.math.uwaterloo.ca>
# 0 the00@plg2.math.uwaterloo.ca
# continue
# <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# smiles@flax9.uwaterloo.ca
# continue
# manager@speedy.uwaterloo.ca
# continue
# <manager@speedy.uwaterloo.ca>
# 0 manager@speedy.uwaterloo.ca
# continue
# Smiles <smiles@flax9.uwaterloo.ca>
# 0 smiles@flax9.uwaterloo.ca
# continue
# samba-technical@lists.samba.org
# continue
# "gnitpickd" <gnitpickd@speedy.uwaterloo.ca>
# 0 gnitpickd@speedy.uwaterloo.ca
# continue
# <producttestpanel@speedy.uwaterloo.ca> Precedence: normal
# 0 producttestpanel@speedy.uwaterloo.ca> Precedence: norma
# 1
# ktwarwic@flax9.uwaterloo.ca
# continue
# <soundtrackdeficient@speedy.uwaterloo.ca>
# 0 soundtrackdeficient@speedy.uwaterloo.ca
# continue
# ed02797c@flax9.uwaterloo.ca
# continue
# r-help@stat.math.ethz.ch
# continue
# manager@flax9.uwaterloo.ca
# continue
# ip-health@lists.essential.org content-transfer-encoding: 7bit content-type: text/plain;  charset=ISO-8859-1;  format=flowed
# 1
# beginners@perl.org
# continue
# samba-cvs@samba.org
# continue
# "Marianela Brooks" <mail@speedy.uwaterloo.ca>
# 0 mail@speedy.uwaterloo.ca
# continue
# avcooper@flax9.uwaterloo.ca Precedence: list
# 1
# <maddy@undergrad.math.uwaterloo.ca>
# 0 maddy@undergrad.math.uwaterloo.ca
# continue
# mudle <mudle@flax9.uwaterloo.ca>
# 0 mudle@flax9.uwaterloo.ca
# continue
# "mailn" <mailn@speedy.uwaterloo.ca>
# 0 mailn@speedy.uwaterloo.ca
# continue
# the00@plg2.math.uwaterloo.ca
# continue
# Zombie Warwick <ktwarwic@speedy.uwaterloo.ca>
# 0 ktwarwic@speedy.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# sugar@laptop.org
# continue
# samba-cvs@samba.org
# continue
# email1506@speedy.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# <the00@plg2.math.uwaterloo.ca>
# 0 the00@plg2.math.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# perl6-language@perl.org
# continue
# <ktwarwic@flax9.uwaterloo.ca>
# 0 ktwarwic@flax9.uwaterloo.ca
# continue
# <smile@speedy.uwaterloo.ca>
# 0 smile@speedy.uwaterloo.ca
# continue
# "Mathew Snyder" <theillien@yahoo.com>
# 0 theillien@yahoo.com
# continue
# <the00@plg2.math.uwaterloo.ca>
# 0 the00@plg2.math.uwaterloo.ca
# continue
# "Speakup is a screen review system for Linux." <speakup@braille.uwo.ca>
# 0 speakup@braille.uwo.ca
# continue
# email396@speedy.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# wisdom <wisdom@flax24.uwaterloo.ca>
# 0 wisdom@flax24.uwaterloo.ca
# continue
# <ktwarwic@flax9.uwaterloo.ca>
# 0 ktwarwic@flax9.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# Volker.Lendecke@SerNet.DE
# continue
# <mhln@mhlearningnetwork.com>
# 0 mhln@mhlearningnetwork.com
# continue
# Ip-health <ip-health@lists.essential.org>
# 0 ip-health@lists.essential.org
# continue
# smiles@flax9.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# <mhln@mhlearningnetwork.com>
# 0 mhln@mhlearningnetwork.com
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# "smilesn" <smilesn@speedy.uwaterloo.ca>
# 0 smilesn@speedy.uwaterloo.ca
# continue
# "mhln" <mhln@mhlearningnetwork.com>
# 0 mhln@mhlearningnetwork.com
# continue
# Acm <the00@plg2.math.uwaterloo.ca>
# 0 the00@plg2.math.uwaterloo.ca
# continue
# manager@speedy.uwaterloo.ca
# continue
# Jonathan Lang <dataweaver@gmail.com>
# 0 dataweaver@gmail.com
# continue
# "Andrew Coopers" <avcooper@flax9.uwaterloo.ca>
# 0 avcooper@flax9.uwaterloo.ca
# continue
# nan
# gnitpick@flax9.uwaterloo.ca
# continue
# themadvlad@speedy.uwaterloo.ca
# continue
# gjditchf@plg.uwaterloo.ca
# continue
# r-help@stat.math.ethz.ch
# continue
# "=?iso-8859-1?Q?ktwarwic@speedy=2Euwaterloo=2Eca=20?=" <ktwarwic@speedy.uwaterloo.ca>
# 0 ktwarwic@speedy.uwaterloo.ca
# continue
# <no-reply@info.net>
# 0 no-reply@info.net
# continue
# aqdokgdvtbj@flax24.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# chromatic <chromatic@wgz.org>
# 0 chromatic@wgz.org
# continue
# <elaastic@speedy.uwaterloo.ca>
# 0 elaastic@speedy.uwaterloo.ca
# continue
# r-help@stat.math.ethz.ch
# continue
# manager@flax9.uwaterloo.ca
# continue
# bugs-bitbucket@netlabs.develooper.com
# continue
# "Speakup is a screen review system for Linux." <speakup@braille.uwo.ca>
# 0 speakup@braille.uwo.ca
# continue
# "Andy Spieherty" <spiehera@lafayette.edu>
# 0 spiehera@lafayette.edu
# continue
# <elaastic@speedy.uwaterloo.ca>
# 0 elaastic@speedy.uwaterloo.ca
# continue
# opt4@flax9.uwaterloo.ca
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# r-help@stat.math.ethz.ch
# continue
# the00@plg2.math.uwaterloo.ca
# continue
# James Peach <jpeach@samba.org>
# 0 jpeach@samba.org
# continue
# debian-devel@lists.debian.org
# continue
# the00@flax9.uwaterloo.ca
# continue
# debian-desktop@lists.debian.org
# continue
# <deficient@speedy.uwaterloo.ca>
# 0 deficient@speedy.uwaterloo.ca
# continue
# email886@speedy.uwaterloo.ca
# continue
# <ktwarwic@speedy.uwaterloo.ca>
# 0 ktwarwic@speedy.uwaterloo.ca
# continue
# manager@flax9.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# jegdcorxchqgnitpick@flax9.uwaterloo.ca
# continue
# email1633@speedy.uwaterloo.ca
# continue
# email841@speedy.uwaterloo.ca
# continue
# mail@speedy.uwaterloo.ca
# continue
# <avcooper@flax9.uwaterloo.ca>
# 0 avcooper@flax9.uwaterloo.ca
# continue
# beginners@perl.org
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# snozzled <snozzled@flax24.uwaterloo.ca>
# 0 snozzled@flax24.uwaterloo.ca
# continue
# <catchall@flax9.uwaterloo.ca>
# 0 catchall@flax9.uwaterloo.ca
# continue
# nan
# "Speakup is a screen review system for Linux." <speakup@braille.uwo.ca>
# 0 speakup@braille.uwo.ca
# continue
# "smilenn" <smilenn@speedy.uwaterloo.ca>
# 0 smilenn@speedy.uwaterloo.ca
# continue
# gjditchf@plg.uwaterloo.ca
# continue
# furmanfw@flax9.uwaterloo.ca
# continue
# ktwarwic@SPEEDY.UWATERLOO.CA
# continue
# "xpRt.wannabe" <xprt.wannabe@gmail.com>
# 0 xprt.wannabe@gmail.com
# continue
# myrtless@speedy.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# Stephen Henderson <s.henderson@ucl.ac.uk> References: <61B482B74D6EE443B90356E080476E340189529A@exc2.cruciform.wibr.ucl.ac.uk>
# 0 s.henderson@ucl.ac.uk> References: <61B482B74D6EE443B90356E080476E340189529A@exc2.cruciform.wibr.ucl.ac.uk
# continue
# <ktwarwic@flax9.uwaterloo.ca>
# 0 ktwarwic@flax9.uwaterloo.ca
# continue
# dunn@usq.edu.au
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# <aholt@plg.uwaterloo.ca>
# 0 aholt@plg.uwaterloo.ca
# continue
# "John W. Krahn" <krahnj@telus.net>
# 0 krahnj@telus.net
# continue
# producttestpanel@flax9.uwaterloo.ca
# continue
# ktwarwic@speedy.uwaterloo.ca
# continue
# rec-music-gaffa@moderators.isc.org
# continue
# <producttestpanel@speedy.uwaterloo.ca> Precedence: normal
# 0 producttestpanel@speedy.uwaterloo.ca> Precedence: norma
# 1
# r-help@stat.math.ethz.ch
# continue
# "mailn" <mailn@speedy.uwaterloo.ca>
# 0 mailn@speedy.uwaterloo.ca
# continue
# ktwarwic@speedy.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# "Roberto Wesley" <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# debian-laptop@lists.debian.org
# continue
# Greg Snow <Greg.Snow@intermountainmail.org>
# 0 Greg.Snow@intermountainmail.org
# continue
# Elaastic <elaastic@flax9.uwaterloo.ca>
# 0 elaastic@flax9.uwaterloo.ca
# continue
# Ktwarwic <ktwarwic@flax9.uwaterloo.ca>
# 0 ktwarwic@flax9.uwaterloo.ca
# continue
# email2097@speedy.uwaterloo.ca
# continue
# Hubert Figuiere <hub@figuiere.net>
# 0 hub@figuiere.net
# continue
# CC Developer Mailing List <cc-devel@lists.ibiblio.org>
# 0 cc-devel@lists.ibiblio.org
# continue
# "avcavc" <ktwarwic@speedy.uwaterloo.ca>
# 0 ktwarwic@speedy.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# <mail@flax9.uwaterloo.ca>
# 0 mail@flax9.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# "suman Duvvuru" <duvvuru.suman@gmail.com>
# 0 duvvuru.suman@gmail.com
# continue
# <theplg@speedy.uwaterloo.ca>
# 0 theplg@speedy.uwaterloo.ca
# continue
# Michael Adam <ma@sernet.de> References: <20070530224312.3B646162ADE@lists.samba.org> 	<E1HtWvm-0008NM-SS@intern.SerNet.DE>
# 0 ma@sernet.de> References: <20070530224312.3B646162ADE@lists.samba.org> 	<E1HtWvm-0008NM-SS@intern.SerNet.DE
# continue
# Wisdom <wisdom@flax24.uwaterloo.ca>
# 0 wisdom@flax24.uwaterloo.ca
# continue
# cruiseca@speedy.uwaterloo.ca
# continue
# <gnitpick@speedy.uwaterloo.ca>
# 0 gnitpick@speedy.uwaterloo.ca
# continue
# ktwarwic@speedy.uwaterloo.ca
# continue
# catchall <catchall@flax9.uwaterloo.ca>
# 0 catchall@flax9.uwaterloo.ca
# continue
# BREAKINGNEWS Subscribers<BREAKINGNEWS-Subscribers@foxnews.com>
# 0 BREAKINGNEWS-Subscribers@foxnews.com
# continue
# <mhln@mhlearningnetwork.com>
# 0 mhln@mhlearningnetwork.com
# continue
# <captains@flax24.uwaterloo.ca>
# 0 captains@flax24.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# \BIGPONDCOMKH.TXT@flax9.uwaterloo.ca
# continue
# \CAMNETCOMKH.TXT@flax9.uwaterloo.ca
# continue
# \KH.TXT@flax9.uwaterloo.ca
# continue
# CVTELECOMCV@flax9.uwaterloo.ca
# continue
# Theorize <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# <gnitpick@speedy.uwaterloo.ca>
# 0 gnitpick@speedy.uwaterloo.ca
# continue
# nan
# the00@plg2.math.uwaterloo.ca
# continue
# ktwarwic@speedy.uwaterloo.ca
# continue
# "=?iso-8859-1?Q?ktwarwic@speedy=2Euwaterloo=2Eca=20?=" <ktwarwic@flax9.uwaterloo.ca>
# 0 ktwarwic@flax9.uwaterloo.ca
# continue
# adtrevors@plg.uwaterloo.ca
# continue
# "Andrew Coopers" <avcooper@flax9.uwaterloo.ca>
# 0 avcooper@flax9.uwaterloo.ca
# continue
# "smilesn" <smilesn@speedy.uwaterloo.ca>
# 0 smilesn@speedy.uwaterloo.ca
# continue
# "Subscriber" <producttestpanel@speedy.uwaterloo.ca>
# 0 producttestpanel@speedy.uwaterloo.ca
# continue
# Netsearch <netsearch@canola1.uwaterloo.ca>
# 0 netsearch@canola1.uwaterloo.ca
# continue
# r-help@stat.math.ethz.ch
# continue
# "theorize" <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# <ktwarwic@flax9.uwaterloo.ca>
# 0 ktwarwic@flax9.uwaterloo.ca
# continue
# "Anthony W. Youngman" <debian@thewolery.demon.co.uk>
# 0 debian@thewolery.demon.co.uk
# continue
# Debian-legal <debian-legal@lists.debian.org>
# 0 debian-legal@lists.debian.org
# continue
# theorize@plg.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# <gnitpick@flax9.uwaterloo.ca>
# 0 gnitpick@flax9.uwaterloo.ca
# continue
# "Chuck Cleland" <ccleland@optonline.net>
# 0 ccleland@optonline.net
# continue
# email2055@speedy.uwaterloo.ca
# continue
# cc-community@lists.ibiblio.org
# continue
# ktwarwic@flax9.UWATERLOO.CA
# continue
# adtrevors@plg.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# <ktwarwic@speedy.uwaterloo.ca>
# 0 ktwarwic@speedy.uwaterloo.ca
# continue
# debian-mirrors@lists.debian.org
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# manager@flax9.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# mhln@mhlearningnetwork.com
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# jewellaqdokgdvtbj@flax9.uwaterloo.ca
# continue
# ktwarwic-plg@flax9.uwaterloo.ca
# continue
# <avcooper@speedy.uwaterloo.ca>
# 0 avcooper@speedy.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# "R-Help" <r-help@stat.math.ethz.ch>
# 0 r-help@stat.math.ethz.ch
# continue
# "Subscriber" <cruiseca@flax9.uwaterloo.ca>
# 0 cruiseca@flax9.uwaterloo.ca
# continue
# "theorize" <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# r-help@stat.math.ethz.ch
# continue
# nan
# <manager@speedy.uwaterloo.ca>
# 0 manager@speedy.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# the00@plg2.math.uwaterloo.ca
# continue
# <manager@flax9.uwaterloo.ca>
# 0 manager@flax9.uwaterloo.ca
# continue
# samba-technical@lists.samba.org
# continue
# gnitpick@speedy.uwaterloo.ca
# continue
# bugs-bitbucket@netlabs.develooper.com
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# "Andrew Coopers" <avcooper@speedy.uwaterloo.ca>
# 0 avcooper@speedy.uwaterloo.ca
# continue
# elaastic@speedy.uwaterloo.ca
# continue
# TDJ <n4nhEKogfty6pfvI@spambox.info>
# 0 n4nhEKogfty6pfvI@spambox.info
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# email633@speedy.uwaterloo.ca
# continue
# <ktwarwic@flax24.uwaterloo.ca>
# 0 ktwarwic@flax24.uwaterloo.ca
# continue
# mack@flax9.uwaterloo.ca
# continue
# "'r-help@stat.math.ethz.ch'" <r-help@stat.math.ethz.ch>
# 0 r-help@stat.math.ethz.ch
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# "Subscriber" <producttestpanel@flax9.uwaterloo.ca>
# 0 producttestpanel@flax9.uwaterloo.ca
# continue
# mister_bluesman <mister_bluesman@hotmail.com> References: <10357828.post@talk.nabble.com> <46403FBA.3070108@bitwrit.com.au> 	<10404970.post@talk.nabble.com>
# 0 mister_bluesman@hotmail.com> References: <10357828.post@talk.nabble.com> <46403FBA.3070108@bitwrit.com.au> 	<10404970.post@talk.nabble.com
# continue
# Snozzled <snozzled@flax24.uwaterloo.ca>
# 0 snozzled@flax24.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# <gnitpick@flax9.uwaterloo.ca>
# 0 gnitpick@flax9.uwaterloo.ca
# continue
# email457@speedy.uwaterloo.ca
# continue
# <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# r-help@stat.math.ethz.ch
# continue
# love-hounds@gaffa.org
# continue
# "gnitpick" <gnitpick@speedy.uwaterloo.ca>
# 0 gnitpick@speedy.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# "Duncan Murdoch" <murdoch@stats.uwo.ca>
# 0 murdoch@stats.uwo.ca
# continue
# catchall@flax9.uwaterloo.ca
# continue
# "It's that simple fuckhead. You Keep Spamming ME I keep ordering." <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# Zombie Warwick <ktwarwic@speedy.uwaterloo.ca>
# 0 ktwarwic@speedy.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# speakup@braille.uwo.ca
# continue
# <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# sugar@laptop.org
# continue
# r-help@stat.math.ethz.ch
# continue
# <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# "Speakup is a screen review system for Linux." <speakup@braille.uwo.ca>
# 0 speakup@braille.uwo.ca
# continue
# <ktwarwic@SPEEDY.UWATERLOO.CA>
# 0 ktwarwic@SPEEDY.UWATERLOO.CA
# continue
# "Mail" <mail@flax9.uwaterloo.ca>
# 0 mail@flax9.uwaterloo.ca
# continue
# <the00@plg2.math.uwaterloo.ca>
# 0 the00@plg2.math.uwaterloo.ca
# continue
# r-help@stat.math.ethz.ch
# continue
# "Smiles" <smiles@flax9.uwaterloo.ca>
# 0 smiles@flax9.uwaterloo.ca
# continue
# "Speakup is a screen review system for Linux." <speakup@braille.uwo.ca>
# 0 speakup@braille.uwo.ca
# continue
# <mhln@mhln.com>
# 0 mhln@mhln.com
# continue
# <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# Philippe LAGACHERIE <lagache@supagro.inra.fr>
# 0 lagache@supagro.inra.fr
# continue
# almer@flax24.uwaterloo.ca
# continue
# gnitpick@speedy.uwaterloo.ca
# continue
# manager@speedy.uwaterloo.ca
# continue
# opt4@flax9.uwaterloo.ca
# continue
# refinance@flax9.uwaterloo.ca
# continue
# gnitpick@speedy.uwaterloo.ca
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# Sigbert Klinke <sigbert@wiwi.hu-berlin.de> References: <46811311.2020503@wiwi.hu-berlin.de>
# 0 sigbert@wiwi.hu-berlin.de> References: <46811311.2020503@wiwi.hu-berlin.de
# continue
# mailx@flax9.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# myklass@gmail.com
# continue
# <manager@flax9.uwaterloo.ca>
# 0 manager@flax9.uwaterloo.ca
# continue
# "Mail" <mail@flax9.uwaterloo.ca>
# 0 mail@flax9.uwaterloo.ca
# continue
# catchall <catchall@flax9.uwaterloo.ca>
# 0 catchall@flax9.uwaterloo.ca
# continue
# <9da6ce2e@speedy.uwaterloo.ca>
# 0 9da6ce2e@speedy.uwaterloo.ca
# continue
# <gnitpick@speedy.uwaterloo.ca>
# 0 gnitpick@speedy.uwaterloo.ca
# continue
# DANCHEN@flax9.uwaterloo.ca
# continue
# "Ron Blaschke" <ron@rblasch.org>
# 0 ron@rblasch.org
# continue
# parrotbug-followup@parrotcode.org
# continue
# <a.martino@crismaitalia.it>
# 0 a.martino@crismaitalia.it
# continue
# <r-help@stat.math.ethz.ch>
# 0 r-help@stat.math.ethz.ch
# continue
# <ktwarwic@flax9.uwaterloo.ca>
# 0 ktwarwic@flax9.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# "Speakup is a screen review system for Linux." <speakup@braille.uwo.ca> References: <Pine.LNX.4.64.0705191217540.2730@janeway.homelinux.org><000f01c799cb$5d39ac20$ab00a8c0@tenstac> 	<Pine.LNX.4.64.0705192008230.2730@janeway.homelinux.org>
# 0 speakup@braille.uwo.ca> References: <Pine.LNX.4.64.0705191217540.2730@janeway.homelinux.org><000f01c799cb$5d39ac20$ab00a8c0@tenstac> 	<Pine.LNX.4.64.0705192008230.2730@janeway.homelinux.org
# continue
# kahlia@flax9.uwaterloo.ca
# continue
# <ktwarwic@speedy.uwaterloo.ca>
# 0 ktwarwic@speedy.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# "Subscriber" <cruiseca@flax9.uwaterloo.ca>
# 0 cruiseca@flax9.uwaterloo.ca
# continue
# acmyyyhtml <acmyyyhtml@flax9.uwaterloo.ca>
# 0 acmyyyhtml@flax9.uwaterloo.ca
# continue
# "Marco Pesenti Gritti" <mpg@redhat.com>
# 0 mpg@redhat.com
# continue
# <vcoopers@speedy.uwaterloo.ca>
# 0 vcoopers@speedy.uwaterloo.ca
# continue
# "antelopehndd" <antelopehndd@speedy.uwaterloo.ca>
# 0 antelopehndd@speedy.uwaterloo.ca
# continue
# "theorize" <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# "Dr.Ruud" <rvtol+news@isolution.nl>
# 0 rvtol+news@isolution.nl
# continue
# "Ramiro" <ramiro@flax9.uwaterloo.ca>
# 0 ramiro@flax9.uwaterloo.ca
# continue
# "gnitpick" <gnitpick@speedy.uwaterloo.ca>
# 0 gnitpick@speedy.uwaterloo.ca
# continue
# <ktwarwic@speedy.uwaterloo.ca>
# 0 ktwarwic@speedy.uwaterloo.ca
# continue
# debian-legal@lists.debian.org
# continue
# the00@plg.uwaterloo.ca
# continue
# "mhln" <mhln@mhlearningnetwork.com>
# 0 mhln@mhlearningnetwork.com
# continue
# Bernhard Schmalhofer via RT <parrotbug-followup@parrotcode.org>
# 0 parrotbug-followup@parrotcode.org
# continue
# undisclosed-recipients:;
# 1
# the00@plg2.math.uwaterloo.ca
# continue
# ip-health@lists.essential.org content-type: text/plain;  charset=ISO-8859-1;  format=flowed
# 1
# <mail@flax9.uwaterloo.ca>
# 0 mail@flax9.uwaterloo.ca
# continue
# beginners@perl.org
# continue
# theorize@plg.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# manager@flax9.uwaterloo.ca
# continue
# mail@flax9.uwaterloo.ca
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# <cforall@plg.uwaterloo.ca>
# 0 cforall@plg.uwaterloo.ca
# continue
# <ktwarwic@flax9.uwaterloo.ca>
# 0 ktwarwic@flax9.uwaterloo.ca
# continue
# "Speakup is a screen review system for Linux." <speakup@braille.uwo.ca> Sent: Sunday
# 0 speakup@braille.uwo.ca> Sent: Sunda
# 1
# Perl Beginners <beginners@perl.org>
# 0 beginners@perl.org
# continue
# <manager@speedy.uwaterloo.ca>
# 0 manager@speedy.uwaterloo.ca
# continue
# gnitpick@speedy.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# email1943@speedy.uwaterloo.ca
# continue
# smiles@flax9.uwaterloo.ca
# continue
# chromatic via RT <parrotbug-followup@parrotcode.org>
# 0 parrotbug-followup@parrotcode.org
# continue
# manager@speedy.uwaterloo.ca
# continue
# bugs-bitbucket@netlabs.develooper.com
# continue
# samba-cvs@samba.org
# continue
# ip-health@lists.essential.org
# continue
# <soundtrackdeficient@speedy.uwaterloo.ca>
# 0 soundtrackdeficient@speedy.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# "Gnitpick" <gnitpick@flax9.uwaterloo.ca>
# 0 gnitpick@flax9.uwaterloo.ca
# continue
# samba-technical@samba.org
# continue
# email16@speedy.uwaterloo.ca
# continue
# shoekbhorror@flax9.uwaterloo.ca
# continue
# opt4@flax9.uwaterloo.ca
# continue
# ktwarwic-plg@flax9.uwaterloo.ca
# continue
# Perl Beginners <beginners@perl.org>
# 0 beginners@perl.org
# continue
# gnitpick@speedy.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# TEXTBREAKINGNEWS@CNNIMAIL12.CNN.COM
# continue
# samba-cvs@samba.org
# continue
# the00@plg.uwaterloo.ca
# continue
# "Louvenia Sanchez" <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# "Speakup is a screen review system for Linux." <speakup@braille.uwo.ca>
# 0 speakup@braille.uwo.ca
# continue
# <9ec06fdb@flax9.uwaterloo.ca>
# 0 9ec06fdb@flax9.uwaterloo.ca
# continue
# "Subscriber" <producttestpanel@flax9.uwaterloo.ca>
# 0 producttestpanel@flax9.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# ktwarwic@speedy.uwaterloo.ca
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# manager@flax9.uwaterloo.ca
# continue
# "theorize" <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# nan
# R-help@stat.math.ethz.ch
# continue
# "Katrina" <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# "Subscriber" <producttestpanel@flax9.uwaterloo.ca>
# 0 producttestpanel@flax9.uwaterloo.ca
# continue
# perl6-internals@perl.org
# continue
# email1974@speedy.uwaterloo.ca
# continue
# mhln@mhln.com
# continue
# <sktwarwic@speedy.uwaterloo.ca>
# 0 sktwarwic@speedy.uwaterloo.ca
# continue
# "Y G" <gatemaze@gmail.com>
# 0 gatemaze@gmail.com
# continue
# theorize@plg.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# r-help@stat.math.ethz.ch
# continue
# <catchall@flax9.uwaterloo.ca>
# 0 catchall@flax9.uwaterloo.ca
# continue
# netsearch@canola1.uwaterloo.ca
# continue
# catchall@speedy.uwaterloo.ca
# continue
# chromatic <chromatic@wgz.org>
# 0 chromatic@wgz.org
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# antelopehn@flax9.uwaterloo.ca
# continue
# "Patrick R. Michaud" <pmichaud@pobox.com>
# 0 pmichaud@pobox.com
# continue
# <the00@plg.uwaterloo.ca> Sent: Thursday
# 0 the00@plg.uwaterloo.ca> Sent: Thursda
# 1
# samba-cvs@samba.org
# continue
# beginners@perl.org
# continue
# Stephen Tucker <brown_emu@yahoo.com>
# 0 brown_emu@yahoo.com
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# bugs-bitbucket@netlabs.develooper.com
# continue
# <speakup@braille.uwo.ca> Sent: Saturday
# 0 speakup@braille.uwo.ca> Sent: Saturda
# 1
# "Manager" <manager@flax9.uwaterloo.ca>
# 0 manager@flax9.uwaterloo.ca
# continue
# mail@flax9.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# "Aron" <catchall@speedy.uwaterloo.ca>
# 0 catchall@speedy.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# the00@plg2.math.uwaterloo.ca
# continue
# miles@flax9.uwaterloo.ca
# continue
# refinance@flax24.uwaterloo.ca
# continue
# <aholt@plg.uwaterloo.ca>
# 0 aholt@plg.uwaterloo.ca
# continue
# undisclosed-recipients:;
# 1
# BREAKINGNEWS Subscribers<BREAKINGNEWS-Subscribers@foxnews.com>
# 0 BREAKINGNEWS-Subscribers@foxnews.com
# continue
# ktwarwic@SPEEDY.UWATERLOO.CA
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# "Jjosh" <jjosh@speedy.uwaterloo.ca>
# 0 jjosh@speedy.uwaterloo.ca
# continue
# <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# "gnitpick" <gnitpick@speedy.uwaterloo.ca>
# 0 gnitpick@speedy.uwaterloo.ca
# continue
# smile@flax9.uwaterloo.ca
# continue
# "Inman
# mj@ut.ee
# continue
# "Webmaster" <webmaster@flax24.uwaterloo.ca>
# 0 webmaster@flax24.uwaterloo.ca
# continue
# producttestpanel@flax9.uwaterloo.ca
# continue
# email1457@speedy.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# <mailnn@flax9.uwaterloo.ca>
# 0 mailnn@flax9.uwaterloo.ca
# continue
# <deficient@flax9.uwaterloo.ca>
# 0 deficient@flax9.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# <mail@flax9.uwaterloo.ca>
# 0 mail@flax9.uwaterloo.ca
# continue
# manager@flax9.uwaterloo.ca
# continue
# =?UTF-8?Q?Ivan_Krsti=C4=87?= <krstic@solarsail.hcs.harvard.edu>
# 0 krstic@solarsail.hcs.harvard.edu
# continue
# "Rodrigo Tavares" <digolinopage@yahoo.com.br>
# 0 digolinopage@yahoo.com.br
# continue
# "Lynsey Harvey" <dmason@plg2.math.uwaterloo.ca>
# 0 dmason@plg2.math.uwaterloo.ca
# continue
# mail@speedy.uwaterloo.ca
# continue
# <tabvrttypmcbgnitpick@speedy.uwaterloo.ca>
# 0 tabvrttypmcbgnitpick@speedy.uwaterloo.ca
# continue
# opt4@flax9.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# Robert Wilkins <irishhacker@gmail.com> References: <874da0b40706071701m55cd42fem15f55a8fcde04f17@mail.gmail.com>
# 0 irishhacker@gmail.com> References: <874da0b40706071701m55cd42fem15f55a8fcde04f17@mail.gmail.com
# continue
# nan
# the00@plg.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# "Subscriber" <cruiseca@flax9.uwaterloo.ca>
# 0 cruiseca@flax9.uwaterloo.ca
# continue
# ktwarwic-plg@flax9.uwaterloo.ca
# continue
# opt4@flax9.uwaterloo.ca
# continue
# opt17@flax9.uwaterloo.ca
# continue
# ktwarwick@plg.uwaterloo.ca
# continue
# rcbilson@plg.uwaterloo.ca
# continue
# aeehassa@plg.uwaterloo.ca
# continue
# itbowman@plg.uwaterloo.ca
# continue
# henna@plg.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# elterra@plg.uwaterloo.ca
# continue
# ktwarwic@speedy.uwaterloo.ca
# continue
# ip-health@lists.essential.org
# continue
# <mailnn@flax9.uwaterloo.ca>
# 0 mailnn@flax9.uwaterloo.ca
# continue
# udhop@flax24.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# chromatic <chromatic@wgz.org>
# 0 chromatic@wgz.org
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# <catchall@flax9.uwaterloo.ca>
# 0 catchall@flax9.uwaterloo.ca
# continue
# producttestpanel@speedy.uwaterloo.ca
# continue
# "the00" <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# "gnitpick" <gnitpick@speedy.uwaterloo.ca>
# 0 gnitpick@speedy.uwaterloo.ca
# continue
# R-Help <r-help@stat.math.ethz.ch>
# 0 r-help@stat.math.ethz.ch
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# <smiles@flax9.uwaterloo.ca>
# 0 smiles@flax9.uwaterloo.ca
# continue
# smiles@flax9.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# <manager@flax9.uwaterloo.ca>
# 0 manager@flax9.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# "manager" <manager@speedy.uwaterloo.ca>
# 0 manager@speedy.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# "Theorize" <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# email1064@speedy.uwaterloo.ca
# continue
# email1361@speedy.uwaterloo.ca
# continue
# <ktwarwic@flax9.uwaterloo.ca>
# 0 ktwarwic@flax9.uwaterloo.ca
# continue
# "mhln" <mhln@mhln.com>
# 0 mhln@mhln.com
# continue
# Perl Beginners <beginners@perl.org>
# 0 beginners@perl.org
# continue
# samba-cvs@samba.org
# continue
# "theorize" <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# gjditchf@plg.uwaterloo.ca
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# R-help@stat.math.ethz.ch
# continue
# catchall@speedy.uwaterloo.ca
# continue
# catchall@speedy.uwaterloo.ca
# continue
# "Ramiro" <ramiro@flax9.uwaterloo.ca>
# 0 ramiro@flax9.uwaterloo.ca
# continue
# Multiple recipients of list SAMBA-TECHNICAL <samba-technical@samba.org>
# 0 samba-technical@samba.org
# continue
# mhln@mhlearningnetwork.com
# continue
# r-help@stat.math.ethz.ch
# continue
# catchall@flax9.uwaterloo.ca
# continue
# producttestpanel@flax9.uwaterloo.ca
# continue
# beginners@perl.org
# continue
# perl6-internals@perl.org
# continue
# Acm <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# <9da6ce2e@flax9.uwaterloo.ca>
# 0 9da6ce2e@flax9.uwaterloo.ca
# continue
# gnitpick@speedy.uwaterloo.ca
# continue
# captains@flax24.uwaterloo.ca
# continue
# email2350@speedy.uwaterloo.ca
# continue
# <mailn@flax9.uwaterloo.ca>
# 0 mailn@flax9.uwaterloo.ca
# continue
# "Gregory I. Clifford" <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# "Spilak
# <gnitpick@flax9.uwaterloo.ca>
# 0 gnitpick@flax9.uwaterloo.ca
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# email647@speedy.uwaterloo.ca
# continue
# <gnitpick@flax9.uwaterloo.ca>
# 0 gnitpick@flax9.uwaterloo.ca
# continue
# <captains@flax24.uwaterloo.ca>
# 0 captains@flax24.uwaterloo.ca
# continue
# <beginners@perl.org>
# 0 beginners@perl.org
# continue
# gnitpick@speedy.uwaterloo.ca
# continue
# sugar@laptop.org
# continue
# <gnitpick@flax9.uwaterloo.ca>
# 0 gnitpick@flax9.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# <gnitpick@speedy.uwaterloo.ca>
# 0 gnitpick@speedy.uwaterloo.ca
# continue
# "ktwarwic" <ktwarwic@speedy.uwaterloo.ca>
# 0 ktwarwic@speedy.uwaterloo.ca
# continue
# beginners@perl.org
# continue
# debian-laptop <debian-laptop@lists.debian.org>
# 0 debian-laptop@lists.debian.org
# continue
# snozzled <snozzled@flax24.uwaterloo.ca>
# 0 snozzled@flax24.uwaterloo.ca
# continue
# samba-cvs@lists.samba.org
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# <gnitpick@speedy.uwaterloo.ca>
# 0 gnitpick@speedy.uwaterloo.ca
# continue
# <ktwarwic@speedy.uwaterloo.ca>
# 0 ktwarwic@speedy.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# Captains <captains@flax24.uwaterloo.ca>
# 0 captains@flax24.uwaterloo.ca
# continue
# Zombie Warwick <ktwarwic@flax9.uwaterloo.ca>
# 0 ktwarwic@flax9.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# "tyrone olin" <gnitpick@flax9.uwaterloo.ca>
# 0 gnitpick@flax9.uwaterloo.ca
# continue
# 9ec06fdb <9ec06fdb@flax9.uwaterloo.ca>
# 0 9ec06fdb@flax9.uwaterloo.ca
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# <elaastic@speedy.uwaterloo.ca>
# 0 elaastic@speedy.uwaterloo.ca
# continue
# ip-health@lists.essential.org
# continue
# e-drug@healthnet.org
# continue
# Sebastian Kruk <residuo.solow@gmail.com> References: <a7961d100706241627g49035513s90d1d91f9e42d622@mail.gmail.com>
# 0 residuo.solow@gmail.com> References: <a7961d100706241627g49035513s90d1d91f9e42d622@mail.gmail.com
# continue
# "r-help@stat.math.ethz.ch" <r-help@stat.math.ethz.ch> Sent: 6/8/07 10:19 AM
# 0 r-help@stat.math.ethz.ch> Sent: 6/8/07 10:19 A
# 1
# avcooper@speedy.uwaterloo.ca Precedence: list
# 1
# TEXTBREAKINGNEWS@CNNIMAIL12.CNN.COM
# continue
# Multiple recipients of list SAMBA-TECHNICAL <samba-technical@samba.org>
# 0 samba-technical@samba.org
# continue
# snozzled@flax24.uwaterloo.ca
# continue
# "mhln" <mhln@mhln.com>
# 0 mhln@mhln.com
# continue
# theorize@plg.uwaterloo.ca
# continue
# <manager@flax9.uwaterloo.ca>
# 0 manager@flax9.uwaterloo.ca
# continue
# <smiles@flax9.uwaterloo.ca>
# 0 smiles@flax9.uwaterloo.ca
# continue
# ramiro@flax9.uwaterloo.ca
# continue
# <the00@plg2.math.uwaterloo.ca>
# 0 the00@plg2.math.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# <r-help@stat.math.ethz.ch> Sent: Friday
# 0 r-help@stat.math.ethz.ch> Sent: Frida
# 1
# <faisalabad@speedy.uwaterloo.ca>
# 0 faisalabad@speedy.uwaterloo.ca
# continue
# <fjburkow@plg.uwaterloo.ca>
# 0 fjburkow@plg.uwaterloo.ca
# continue
# "Bernard" <mail@flax9.uwaterloo.ca>
# 0 mail@flax9.uwaterloo.ca
# continue
# <ktwarwic@speedy.uwaterloo.ca>
# 0 ktwarwic@speedy.uwaterloo.ca
# continue
# beginners@perl.org
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# beginners@perl.org
# continue
# theorize@plg.uwaterloo.ca
# continue
# email1907@speedy.uwaterloo.ca
# continue
# "manager" <manager@speedy.uwaterloo.ca>
# 0 manager@speedy.uwaterloo.ca
# continue
# "Kym Meyer" <the00@plg2.math.uwaterloo.ca>
# 0 the00@plg2.math.uwaterloo.ca
# continue
# dmason@plg.uwaterloo.ca
# continue
# producttestpanel@flax9.uwaterloo.ca
# continue
# chromatic <chromatic@wgz.org>
# 0 chromatic@wgz.org
# continue
# ted.harding@manchester.ac.uk References: <XFMail.070501145048.ted.harding@nessie.mcc.ac.uk>
# 0 XFMail.070501145048.ted.harding@nessie.mcc.ac.uk
# continue
# Andy Lester <andy@petdance.com>
# 0 andy@petdance.com
# continue
# fjburkowski@plg.uwaterloo.ca
# continue
# Dong-hyun Oh <r.arecibo@gmail.com>
# 0 r.arecibo@gmail.com
# continue
# "Sktwarwic" <sktwarwic@flax9.uwaterloo.ca>
# 0 sktwarwic@flax9.uwaterloo.ca
# continue
# email2195@speedy.uwaterloo.ca
# continue
# catchall@flax9.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# Netsearch <netsearch@canola1.uwaterloo.ca>
# 0 netsearch@canola1.uwaterloo.ca
# continue
# adf adf <funnyreign@speedy.uwaterloo.ca>
# 0 funnyreign@speedy.uwaterloo.ca
# continue
# <ktwarwic@flax9.uwaterloo.ca>
# 0 ktwarwic@flax9.uwaterloo.ca
# continue
# "Smiles" <smiles@flax9.uwaterloo.ca> References: <Helena670@purinmail.com>
# 0 smiles@flax9.uwaterloo.ca> References: <Helena670@purinmail.com
# continue
# mhln@mhlearningnetwork.com
# continue
# email977@speedy.uwaterloo.ca
# continue
# manager@speedy.uwaterloo.ca
# continue
# <gnitpick@flax9.uwaterloo.ca>
# 0 gnitpick@flax9.uwaterloo.ca
# continue
# <mail@flax9.uwaterloo.ca>
# 0 mail@flax9.uwaterloo.ca
# continue
# <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# <faisalabad@speedy.uwaterloo.ca>
# 0 faisalabad@speedy.uwaterloo.ca
# continue
# "gnitpick" <gnitpick@speedy.uwaterloo.ca>
# 0 gnitpick@speedy.uwaterloo.ca
# continue
# "Kirby" <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# gjditchf@plg.uwaterloo.ca
# continue
# "Loyce Snyder" <migod@plg2.math.uwaterloo.ca>
# 0 migod@plg2.math.uwaterloo.ca
# continue
# upefd@flax9.uwaterloo.ca
# continue
# <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# Jeremy Allison <jra@samba.org>
# 0 jra@samba.org
# continue
# <theorize@flax9.uwaterloo.ca>
# 0 theorize@flax9.uwaterloo.ca
# continue
# "Subscriber" <producttestpanel@speedy.uwaterloo.ca>
# 0 producttestpanel@speedy.uwaterloo.ca
# continue
# "Speakup is a screen review system for Linux." <speakup@braille.uwo.ca>
# 0 speakup@braille.uwo.ca
# continue
# r-help@stat.math.ethz.ch
# continue
# samba-cvs@samba.org
# continue
# <smiles@speedy.uwaterloo.ca>
# 0 smiles@speedy.uwaterloo.ca
# continue
# <catchall@flax9.uwaterloo.ca>
# 0 catchall@flax9.uwaterloo.ca
# continue
# <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# <mhln@mhln.com>
# 0 mhln@mhln.com
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# email339@speedy.uwaterloo.ca
# continue
# "ktwarwic" <ktwarwic@speedy.uwaterloo.ca>
# 0 ktwarwic@speedy.uwaterloo.ca
# continue
# "Young Cho" <young.stat@gmail.com> References: <b44da9db0705291337p6d3ae53bj1e4e26b3581fe81c@mail.gmail.com>
# 0 young.stat@gmail.com> References: <b44da9db0705291337p6d3ae53bj1e4e26b3581fe81c@mail.gmail.com
# continue
# <smiles@flax9.uwaterloo.ca>
# 0 smiles@flax9.uwaterloo.ca
# continue
# <itbowman@plg.uwaterloo.ca>
# 0 itbowman@plg.uwaterloo.ca
# continue
# snozzled7@flax24.uwaterloo.ca
# continue
# msn-list@te.verweg.com
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# <speakup@braille.uwo.ca> Sent: Monday
# 0 speakup@braille.uwo.ca> Sent: Monda
# 1
# <warwick@speedy.uwaterloo.ca>
# 0 warwick@speedy.uwaterloo.ca
# continue
# "Gerald (Jerry) Carter" <jerry@samba.org>
# 0 jerry@samba.org
# continue
# samba-cvs@samba.org
# continue
# holt@plg.uwaterloo.ca
# continue
# itbowman@plg.uwaterloo.ca
# continue
# aeehassa@plg.uwaterloo.ca
# continue
# aholt@plg.uwaterloo.ca
# continue
# ajmalton@plg.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# adtrevors@plg.uwaterloo.ca
# continue
# <theorize@speedy.uwaterloo.ca>
# 0 theorize@speedy.uwaterloo.ca
# continue
# sigzero@gmail.com
# continue
# beginners@perl.org
# continue
# ktwarwic@speedy.uwaterloo.ca
# continue
# catchall@flax9.uwaterloo.ca
# continue
# <ktwarwic@flax9.uwaterloo.ca>
# 0 ktwarwic@flax9.uwaterloo.ca
# continue
# BREAKINGNEWS Subscribers<BREAKINGNEWS-Subscribers@foxnews.com>
# 0 BREAKINGNEWS-Subscribers@foxnews.com
# continue
# samba-cvs@samba.org
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# <smiles@flax9.uwaterloo.ca>
# 0 smiles@flax9.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# Volker Lendecke <Volker.Lendecke@SerNet.DE>
# 0 Volker.Lendecke@SerNet.DE
# continue
# <maddy@undergrad.math.uwaterloo.ca>
# 0 maddy@undergrad.math.uwaterloo.ca
# continue
# <elaastic@flax9.uwaterloo.ca>
# 0 elaastic@flax9.uwaterloo.ca
# continue
# manager@speedy.uwaterloo.ca
# continue
# "Deepayan Sarkar" <deepayan.sarkar@gmail.com>
# 0 deepayan.sarkar@gmail.com
# continue
# "Elaastic" <elaastic@flax9.uwaterloo.ca>
# 0 elaastic@flax9.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# <mhln@mhlearningnetwork.com>
# 0 mhln@mhlearningnetwork.com
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# email2325@speedy.uwaterloo.ca
# continue
# <gnitpick@speedy.uwaterloo.ca>
# 0 gnitpick@speedy.uwaterloo.ca
# continue
# email63@speedy.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# samba-cvs@samba.org
# continue
# mail@speedy.uwaterloo.ca
# continue
# "Maragret Jackson" <ktwarwic@speedy.uwaterloo.ca>
# 0 ktwarwic@speedy.uwaterloo.ca
# continue
# producttestpanel@speedy.uwaterloo.ca
# continue
# <mail@flax9.uwaterloo.ca>
# 0 mail@flax9.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# perl6-language@perl.org
# continue
# "gnitpick" <gnitpick@flax9.uwaterloo.ca>
# 0 gnitpick@flax9.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# samba-cvs@samba.org
# continue
# <ktwarwic@flax9.uwaterloo.ca>
# 0 ktwarwic@flax9.uwaterloo.ca
# continue
# SmartList <debian-desktop@lists.debian.org>
# 0 debian-desktop@lists.debian.org
# continue
# email1462@speedy.uwaterloo.ca
# continue
# <mack@flax9.uwaterloo.ca>
# 0 mack@flax9.uwaterloo.ca
# continue
# warwick@plg.uwaterloo.ca
# continue
# elterra@plg.uwaterloo.ca
# continue
# fjburkow@plg.uwaterloo.ca
# continue
# fjburkowski@plg.uwaterloo.ca
# continue
# ftp@plg.uwaterloo.ca
# continue
# adtrevors@plg.uwaterloo.ca
# continue
# aeehassa@plg.uwaterloo.ca
# continue
# aholt@plg.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# <aholt@plg.uwaterloo.ca>
# 0 aholt@plg.uwaterloo.ca
# continue
# mhln@mhlearningnetwork.com
# continue
# <ktwarwic@flax9.uwaterloo.ca>
# 0 ktwarwic@flax9.uwaterloo.ca
# continue
# mhln@mhlearningnetwork.com
# continue
# tridge@samba.org
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# ...
# continue
# mack5@flax9.uwaterloo.ca
# continue
# <r-help@stat.math.ethz.ch>
# 0 r-help@stat.math.ethz.ch
# continue
# "mhln" <mhln@mhlearningnetwork.com>
# 0 mhln@mhlearningnetwork.com
# continue
# smiles@speedy.uwaterloo.ca
# continue
# Michael Dewey <med@aghmed.fsnet.co.uk>
# 0 med@aghmed.fsnet.co.uk
# continue
# IP-Health <ip-health@lists.essential.org>
# 0 ip-health@lists.essential.org
# continue
# "mackd" <mackd@speedy.uwaterloo.ca>
# 0 mackd@speedy.uwaterloo.ca
# continue
# mail@speedy.uwaterloo.ca
# continue
# myrtless@flax24.uwaterloo.ca
# continue
# <avcoopers@flax9.uwaterloo.ca>
# 0 avcoopers@flax9.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# smiles@speedy.uwaterloo.ca
# continue
# "Peter Dalgaard" <p.dalgaard@biostat.ku.dk>
# 0 p.dalgaard@biostat.ku.dk
# continue
# "Prof Brian Ripley" <ripley@stats.ox.ac.uk>
# 0 ripley@stats.ox.ac.uk
# continue
# "Spencer Graves" <spencer.graves@pdf.com>
# 0 spencer.graves@pdf.com
# continue
# "Ramiro" <ramiro@flax9.uwaterloo.ca>
# 0 ramiro@flax9.uwaterloo.ca
# continue
# "catchall" <catchall@speedy.uwaterloo.ca>
# 0 catchall@speedy.uwaterloo.ca
# continue
# ip-health@lists.essential.org
# continue
# <the00@plg2.math.uwaterloo.ca>
# 0 the00@plg2.math.uwaterloo.ca
# continue
# <antelopehn@flax9.uwaterloo.ca>
# 0 antelopehn@flax9.uwaterloo.ca
# continue
# Perl Beginners <beginners@perl.org>
# 0 beginners@perl.org
# continue
# mailx@flax9.uwaterloo.ca
# continue
# warwick <warwick@flax9.uwaterloo.ca>
# 0 warwick@flax9.uwaterloo.ca
# continue
# sugar@lists.laptop.org
# continue
# Devel List <devel@lists.laptop.org>
# 0 devel@lists.laptop.org
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# "Lyman" <smiles@flax9.uwaterloo.ca>
# 0 smiles@flax9.uwaterloo.ca
# continue
# "theorize" <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# "Subscriber" <producttestpanel@flax9.uwaterloo.ca>
# 0 producttestpanel@flax9.uwaterloo.ca
# continue
# <ktwarwic@speedy.uwaterloo.ca>
# 0 ktwarwic@speedy.uwaterloo.ca
# continue
# "mhln" <mhln@mhlearningnetwork.com>
# 0 mhln@mhlearningnetwork.com
# continue
# email2250@speedy.uwaterloo.ca
# continue
# producttestpanel@flax9.uwaterloo.ca
# continue
# "The00" <the00@plg2.math.uwaterloo.ca>
# 0 the00@plg2.math.uwaterloo.ca
# continue
# "antelopehnd" <antelopehnd@speedy.uwaterloo.ca>
# 0 antelopehnd@speedy.uwaterloo.ca
# continue
# Debian-legal <debian-legal@lists.debian.org>
# 0 debian-legal@lists.debian.org
# continue
# theorize@speedy.uwaterloo.ca
# continue
# "" <ktwarwic@flax9.uwaterloo.ca>
# 0 ktwarwic@flax9.uwaterloo.ca
# continue
# email792@speedy.uwaterloo.ca
# continue
# r-help@stat.math.ethz.ch
# continue
# <gnitpick@flax9.uwaterloo.ca>
# 0 gnitpick@flax9.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# the00@plg2.math.uwaterloo.ca
# continue
# the00@plg2.math.uwaterloo.ca
# continue
# BREAKINGNEWS Subscribers<BREAKINGNEWS-Subscribers@foxnews.com>
# 0 BREAKINGNEWS-Subscribers@foxnews.com
# continue
# ktwarwic@flax9.UWATERLOO.CA
# continue
# r-help@stat.math.ethz.ch
# continue
# "OtherRecipients of perl Ticket #42897": ;
# 1
# <catchall@flax9.uwaterloo.ca>
# 0 catchall@flax9.uwaterloo.ca
# continue
# Debian-legal <debian-legal@lists.debian.org>
# 0 debian-legal@lists.debian.org
# continue
# "Seth" <mhln@eppg.com>
# 0 mhln@eppg.com
# continue
# debian-laptop@lists.debian.org
# continue
# mhln@mhln.com
# continue
# the00@plg.uwaterloo.ca
# continue
# the00 <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# "theorize" <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# nan
# simpsons@flax24.uwaterloo.ca
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# Kedda <kedda@flax24.uwaterloo.ca>
# 0 kedda@flax24.uwaterloo.ca
# continue
# TEXTBREAKINGNEWS@CNNIMAIL12.CNN.COM
# continue
# samba-cvs@samba.org
# continue
# "Lupe" <migod@plg2.math.uwaterloo.ca>
# 0 migod@plg2.math.uwaterloo.ca
# continue
# gnitpick@speedy.uwaterloo.ca References: <A11771080548512807685.gnitpick@speedy.uwaterloo.ca>
# 0 A11771080548512807685.gnitpick@speedy.uwaterloo.ca
# continue
# <catchall@flax9.uwaterloo.ca>
# 0 catchall@flax9.uwaterloo.ca
# continue
# ktwarwic-plg@flax9.uwaterloo.ca
# continue
# opt4@flax9.uwaterloo.ca
# continue
# the00@flax9.uwaterloo.ca
# continue
# "michael watson (IAH-C)" <michael.watson@bbsrc.ac.uk>
# 0 michael.watson@bbsrc.ac.uk
# continue
# beginners@perl.org
# continue
# debian-laptop@lists.debian.org
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# <the00@plg2.math.uwaterloo.ca>
# 0 the00@plg2.math.uwaterloo.ca
# continue
# "wayland wayland" <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# Jacques Wagnor <jacques.wagnor@gmail.com> References: <463A44B8.7000406@utas.edu.au> 	<787911d50705031421h41628a88v35cb974694b5b64d@mail.gmail.com>
# 0 jacques.wagnor@gmail.com> References: <463A44B8.7000406@utas.edu.au> 	<787911d50705031421h41628a88v35cb974694b5b64d@mail.gmail.com
# continue
# manager@speedy.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# antelopehn@flax9.uwaterloo.ca
# continue
# <ktwarwic@flax9.uwaterloo.ca>
# 0 ktwarwic@flax9.uwaterloo.ca
# continue
# undisclosed-recipients:;
# 1
# Michael B Allen <mba2000@ioplex.com>
# 0 mba2000@ioplex.com
# continue
# beginners@perl.org
# continue
# smiles@speedy.uwaterloo.ca
# continue
# r-help@stat.math.ethz.ch
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# r-help@stat.math.ethz.ch
# continue
# "wheat" <wheat@speedy.uwaterloo.ca>
# 0 wheat@speedy.uwaterloo.ca
# continue
# <gnitpick@flax9.uwaterloo.ca>
# 0 gnitpick@flax9.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# the00@plg.uwaterloo.ca
# continue
# <avcooper@flax9.uwaterloo.ca>
# 0 avcooper@flax9.uwaterloo.ca
# continue
# samba-technical@lists.samba.org References: <20070626081141.08419162ACA@lists.samba.org> 	<4680CD0D.5070508@samba.org>
# 0 20070626081141.08419162ACA@lists.samba.org> 	<4680CD0D.5070508@samba.org
# continue
# <manager@speedy.uwaterloo.ca>
# 0 manager@speedy.uwaterloo.ca
# continue
# elaastic@flax9.uwaterloo.ca
# continue
# producttestpanel@flax9.uwaterloo.ca
# continue
# bugs-bitbucket@netlabs.develooper.com
# continue
# "the00" <the00@plg2.math.uwaterloo.ca>
# 0 the00@plg2.math.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# bugs-bitbucket@netlabs.develooper.com
# continue
# Captains <captains@flax24.uwaterloo.ca>
# 0 captains@flax24.uwaterloo.ca
# continue
# <avcooper@speedy.uwaterloo.ca>
# 0 avcooper@speedy.uwaterloo.ca
# continue
# smile@speedy.uwaterloo.ca
# continue
# "Zombie L. Simpson" <reform@meerschwein.hh.schule.de>
# 0 reform@meerschwein.hh.schule.de
# continue
# <avcooper@speedy.uwaterloo.ca>
# 0 avcooper@speedy.uwaterloo.ca
# continue
# "Staci" <gnitpick@speedy.uwaterloo.ca>
# 0 gnitpick@speedy.uwaterloo.ca
# continue
# <gnitpick@speedy.uwaterloo.ca>
# 0 gnitpick@speedy.uwaterloo.ca
# continue
# aeehassa@plg.uwaterloo.ca
# continue
# aholt@plg.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# adtrevors@plg.uwaterloo.ca
# continue
# "mack" <mack@speedy.uwaterloo.ca>
# 0 mack@speedy.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# <mail@speedy.uwaterloo.ca>
# 0 mail@speedy.uwaterloo.ca
# continue
# <ktwarwic@speedy.uwaterloo.ca>
# 0 ktwarwic@speedy.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# Mhln <mhln@mhlearningnetwork.com>
# 0 mhln@mhlearningnetwork.com
# continue
# email1125@speedy.uwaterloo.ca
# continue
# <gnitpick@flax9.uwaterloo.ca>
# 0 gnitpick@flax9.uwaterloo.ca
# continue
# Acm <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# Kedda <kedda@flax24.uwaterloo.ca>
# 0 kedda@flax24.uwaterloo.ca
# continue
# smiles@sdcoe.net
# continue
# <debian-laptop@lists.debian.org> References: <58a4fe090704271251t1ab99f82wc0cfa09d3627c0cc@mail.gmail.com><db5661d60704280054s72314e61x82ec7dc94f873dd5@mail.gmail.com><58a4fe090704280108k2036806bgeb51c520523d6501@mail.gmail.com><20070428154147.GA7732@cs.utexas.edu><58a4fe090704290317ub8d2b25lf3cb53ffa239492@mail.gmail.com><20070429134117.GA9584@localhost><58a4fe090704300022q19e833d5k65f544f9fbaf1120@mail.gmail.com> <20070430163302.08351d40@gandalf.lan1>
# 0 debian-laptop@lists.debian.org> References: <58a4fe090704271251t1ab99f82wc0cfa09d3627c0cc@mail.gmail.com><db5661d60704280054s72314e61x82ec7dc94f873dd5@mail.gmail.com><58a4fe090704280108k2036806bgeb51c520523d6501@mail.gmail.com><20070428154147.GA7732@cs.utexas.edu><58a4fe090704290317ub8d2b25lf3cb53ffa239492@mail.gmail.com><20070429134117.GA9584@localhost><58a4fe090704300022q19e833d5k65f544f9fbaf1120@mail.gmail.com> <20070430163302.08351d40@gandalf.lan1
# continue
# aholt@plg.uwaterloo.ca
# continue
# warwick@plg.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# dziegler@plg.uwaterloo.ca
# continue
# aeehassa@plg.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# opt2@flax9.uwaterloo.ca
# continue
# smiles@flax9.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# mail@flax9.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# ron@rblasch.org
# continue
# vcoopers@speedy.uwaterloo.ca
# continue
# <gnitpick@flax9.uwaterloo.ca>
# 0 gnitpick@flax9.uwaterloo.ca
# continue
# "Netsearch" <netsearch@canola1.uwaterloo.ca>
# 0 netsearch@canola1.uwaterloo.ca
# continue
# "captains@wheat.uwaterloo.ca"<captains@flax24.uwaterloo.ca>
# 0 captains@flax24.uwaterloo.ca
# continue
# <emailreach@speedy.uwaterloo.ca>
# 0 emailreach@speedy.uwaterloo.ca
# continue
# <the00@plg2.math.uwaterloo.ca>
# 0 the00@plg2.math.uwaterloo.ca
# continue
# producttestpanel@flax9.uwaterloo.ca
# continue
# aqdokgdvtbj <aqdokgdvtbj@flax24.uwaterloo.ca>
# 0 aqdokgdvtbj@flax24.uwaterloo.ca
# continue
# <gnitpick@flax9.uwaterloo.ca>
# 0 gnitpick@flax9.uwaterloo.ca
# continue
# tridge@samba.org
# continue
# "corbett minnaminnie" <kedda@flax24.uwaterloo.ca>
# 0 kedda@flax24.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# deficient@flax9.uwaterloo.ca
# continue
# debian-desktop@lists.debian.org
# continue
# <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# nan
# Volker.Lendecke@SerNet.DE
# continue
# <gnitpick@flax9.uwaterloo.ca>
# 0 gnitpick@flax9.uwaterloo.ca
# continue
# manager@speedy.uwaterloo.ca
# continue
# <manager@speedy.uwaterloo.ca>
# 0 manager@speedy.uwaterloo.ca
# continue
# nan
# tridge@samba.org References: <17974.47767.529755.421304@samba.org>
# 0 17974.47767.529755.421304@samba.org
# continue
# samba-cvs@samba.org
# continue
# themadvlad@speedy.uwaterloo.ca
# continue
# gnitpick@speedy.uwaterloo.ca
# continue
# perl6-internals@perl.org
# continue
# parrotbug-followup@parrotcode.org
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# samba-cvs@samba.org
# continue
# the00@plg.uwaterloo.ca
# continue
# smiles@flax9.uwaterloo.ca
# continue
# "'Sugar List'" <sugar@laptop.org>
# 0 sugar@laptop.org
# continue
# pygtk@daa.com.au
# continue
# John Gilmore <gnu@toad.com>
# 0 gnu@toad.com
# continue
# <gnitpick@flax9.uwaterloo.ca>
# 0 gnitpick@flax9.uwaterloo.ca
# continue
# <mhln@mhlearningnetwork.com>
# 0 mhln@mhlearningnetwork.com
# continue
# "Andrew Coopers" <avcooper@flax9.uwaterloo.ca>
# 0 avcooper@flax9.uwaterloo.ca
# continue
# email233@speedy.uwaterloo.ca
# continue
# beginners@perl.org; beginners-dbi@perl.org
# continue
# nan
# <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# "Speakup is a screen review system for Linux." <speakup@braille.uwo.ca>
# 0 speakup@braille.uwo.ca
# continue
# <smiles@speedy.uwaterloo.ca>
# 0 smiles@speedy.uwaterloo.ca
# continue
# debian-legal@lists.debian.org
# continue
# theorize@plg.uwaterloo.ca
# continue
# <manager@speedy.uwaterloo.ca>
# 0 manager@speedy.uwaterloo.ca
# continue
# damian@conway.org
# continue
# <gnitpick@speedy.uwaterloo.ca>
# 0 gnitpick@speedy.uwaterloo.ca
# continue
# "Sktwarwic" <sktwarwic@speedy.uwaterloo.ca>
# 0 sktwarwic@speedy.uwaterloo.ca
# continue
# gnitpick@speedy.uwaterloo.ca
# continue
# the00@plg.uwaterloo.ca
# continue
# <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# ktwarwic@flax9.uwaterloo.ca
# continue
# <1@speedy.uwaterloo.ca>
# 0 1@speedy.uwaterloo.ca
# continue
# <theorize@plg.uwaterloo.ca>
# 0 theorize@plg.uwaterloo.ca
# continue
# gnitpick@flax9.uwaterloo.ca
# continue
# the00@plg2.math.uwaterloo.ca
# continue
# theorize@plg.uwaterloo.ca
# continue
# <gnitpick@flax9.uwaterloo.ca>
# 0 gnitpick@flax9.uwaterloo.ca
# continue
# Acm <the00@plg.uwaterloo.ca>
# 0 the00@plg.uwaterloo.ca
# continue
# <mail@speedy.uwaterloo.ca>
# 0 mail@speedy.uwaterloo.ca
# continue
# ed@flax9.uwaterloo.ca
# continue
# <r-packages@stat.math.ethz.ch>
# 0 r-packages@stat.math.ethz.ch
# continue
#       Feature2                                                 To
# 4            1   bguenter@gemprint.com \n\n     Is your site l...
# 28           1                                                NaN
# 30           1   bruce.guenter@gemprint.com \n\n     Is your s...
# 38           1   bguenter@linus.vsource.com \n\n     Is your s...
# 48           1                                                NaN
# 108          1       "OtherRecipients of perl Ticket #43325": ;\n
# 139          1   "Speakup is a screen review system for Linux....
# 191          1   <producttestpanel@speedy.uwaterloo.ca>\nPrece...
# 197          1   ip-health@lists.essential.org\ncontent-transf...
# 201          1    avcooper@flax9.uwaterloo.ca\nPrecedence: list\n
# 242          1                                                NaN
# 283          1                                                NaN
# 304          1   <producttestpanel@speedy.uwaterloo.ca>\nPrece...
# 336          1                                                NaN
# 376          1                                                NaN
# 465          1                         undisclosed-recipients:;\n
# 467          1   ip-health@lists.essential.org\ncontent-type: ...
# 474          1   "Speakup is a screen review system for Linux....
# 511          1                                                NaN
# 530          1   <the00@plg.uwaterloo.ca>\nSent: Thursday, Mar...
# 536          1   <speakup@braille.uwo.ca>\nSent: Saturday, May...
# 546          1                         undisclosed-recipients:;\n
# 554          1   "Inman, Brant A.   M.D." <Inman.Brant@mayo.ed...
# 573          1                                                NaN
# 631          1   "Spilak,Jacqueline [Edm]" <Jacqueline.Spilak@...
# 664          1   "r-help@stat.math.ethz.ch" <r-help@stat.math....
# 665          1   avcooper@speedy.uwaterloo.ca\nPrecedence: list\n
# 676          1   <r-help@stat.math.ethz.ch>\nSent: Friday, May...
# 737          1   <speakup@braille.uwo.ca>\nSent: Monday, June ...
# 787          1   "Speakup is a screen review system for Linux....
# ...        ...                                                ...
# 4389         1                                                NaN
# 4400         1   "Speakup is a screen review system for Linux....
# 4406         1       "OtherRecipients of perl Ticket #42919": ;\n
# 4424         1   "Speakup is a screen review system for Linux....
# 4457         1                                                NaN
# 4461         1   <producttestpanel@speedy.uwaterloo.ca>\nPrece...
# 4464         1                                                NaN
# 4465         1       "OtherRecipients of perl Ticket #38217": ;\n
# 4514         1   <producttestpanel@speedy.uwaterloo.ca>\nPrece...
# 4524         1                                                NaN
# 4557         1                                                NaN
# 4579         1                         undisclosed-recipients:;\n
# 4593         1   <r-help@stat.math.ethz.ch>\nSent: Friday, May...
# 4614         1   "Lucke, Joseph F" <Joseph.F.Lucke@uth.tmc.edu...
# 4615         1   <producttestpanel@speedy.uwaterloo.ca>\nPrece...
# 4635         1   r-help <r-help@stat.math.ethz.ch>\nOrganizati...
# 4655         1                         undisclosed-recipients:;\n
# 4697         1                                                NaN
# 4706         1                                                NaN
# 4764         1                                                NaN
# 4789         1                                                NaN
# 4791         1   <producttestpanel@speedy.uwaterloo.ca>\nPrece...
# 4839         1   <producttestpanel@speedy.uwaterloo.ca>\nPrece...
# 4845         1   ip-health@lists.essential.org\ncontent-transf...
# 4901         1       "OtherRecipients of perl Ticket #42897": ;\n
# 4910         1                                                NaN
# 4931         1                         undisclosed-recipients:;\n
# 4994         1                                                NaN
# 4999         1                                                NaN
# 5015         1                                                NaN
#
# [192 rows x 2 columns]

# %%
df_final[df_final['To'].notna() & df_final['Feature2'] == 1][['To','Feature2']]
# Out:
#                                                      To  Feature2
# 4      bguenter@gemprint.com \n\n     Is your site l...         1
# 30     bruce.guenter@gemprint.com \n\n     Is your s...         1
# 38     bguenter@linus.vsource.com \n\n     Is your s...         1
# 108        "OtherRecipients of perl Ticket #43325": ;\n         1
# 139    "Speakup is a screen review system for Linux....         1
# 191    <producttestpanel@speedy.uwaterloo.ca>\nPrece...         1
# 197    ip-health@lists.essential.org\ncontent-transf...         1
# 201     avcooper@flax9.uwaterloo.ca\nPrecedence: list\n         1
# 304    <producttestpanel@speedy.uwaterloo.ca>\nPrece...         1
# 465                          undisclosed-recipients:;\n         1
# 467    ip-health@lists.essential.org\ncontent-type: ...         1
# 474    "Speakup is a screen review system for Linux....         1
# 530    <the00@plg.uwaterloo.ca>\nSent: Thursday, Mar...         1
# 536    <speakup@braille.uwo.ca>\nSent: Saturday, May...         1
# 546                          undisclosed-recipients:;\n         1
# 554    "Inman, Brant A.   M.D." <Inman.Brant@mayo.ed...         1
# 631    "Spilak,Jacqueline [Edm]" <Jacqueline.Spilak@...         1
# 664    "r-help@stat.math.ethz.ch" <r-help@stat.math....         1
# 665    avcooper@speedy.uwaterloo.ca\nPrecedence: list\n         1
# 676    <r-help@stat.math.ethz.ch>\nSent: Friday, May...         1
# 737    <speakup@braille.uwo.ca>\nSent: Monday, June ...         1
# 787    "Speakup is a screen review system for Linux....         1
# 791    <producttestpanel@speedy.uwaterloo.ca>\nPrece...         1
# 825    producttestpanel@flax9.uwaterloo.ca\nx-<mailt...         1
# 901     avcooper@flax9.uwaterloo.ca\nPrecedence: list\n         1
# 912    ip-health@lists.essential.org\ncontent-type: ...         1
# 937    avcooper@speedy.uwaterloo.ca\nPrecedence: list\n         1
# 972    "Speakup is a screen review system for Linux....         1
# 1004                  "Feng, Ken" <ken.feng@citi.com>\n         1
# 1063                               Gabor Grothendieck\n         1
# ...                                                 ...       ...
# 4066   <smiles@speedy.uwaterloo.ca>\nSent: Thursday,...         1
# 4067   "Wagner, David --- Senior Programmer Analyst ...         1
# 4099                         undisclosed-recipients:;\n         1
# 4107   Ip-health@lists.essential.org\ncontent-type: ...         1
# 4109   <mail@speedy.uwaterloo.ca>\nSent: Thursday, M...         1
# 4115   "Speakup is a screen review system for Linux....         1
# 4157   ip-health@lists.essential.org\ncontent-transf...         1
# 4183   Ip-health@lists.essential.org\ncontent-type: ...         1
# 4192   debian-laptop@lists.debian.org\nOrganization:...         1
# 4253   "Vladimir Lemberg" <lemba@sbcglobal.net>; <be...         1
# 4289   "Booman, M" <m.booman@path.umcg.nl>, r-help@s...         1
# 4322   ip-health@lists.essential.org\ncontent-transf...         1
# 4388   "General Copyright Discussions (questions, or...         1
# 4400   "Speakup is a screen review system for Linux....         1
# 4406       "OtherRecipients of perl Ticket #42919": ;\n         1
# 4424   "Speakup is a screen review system for Linux....         1
# 4461   <producttestpanel@speedy.uwaterloo.ca>\nPrece...         1
# 4465       "OtherRecipients of perl Ticket #38217": ;\n         1
# 4514   <producttestpanel@speedy.uwaterloo.ca>\nPrece...         1
# 4579                         undisclosed-recipients:;\n         1
# 4593   <r-help@stat.math.ethz.ch>\nSent: Friday, May...         1
# 4614   "Lucke, Joseph F" <Joseph.F.Lucke@uth.tmc.edu...         1
# 4615   <producttestpanel@speedy.uwaterloo.ca>\nPrece...         1
# 4635   r-help <r-help@stat.math.ethz.ch>\nOrganizati...         1
# 4655                         undisclosed-recipients:;\n         1
# 4791   <producttestpanel@speedy.uwaterloo.ca>\nPrece...         1
# 4839   <producttestpanel@speedy.uwaterloo.ca>\nPrece...         1
# 4845   ip-health@lists.essential.org\ncontent-transf...         1
# 4901       "OtherRecipients of perl Ticket #42897": ;\n         1
# 4931                         undisclosed-recipients:;\n         1
#
# [139 rows x 2 columns]

# %%
import re
def isValidMessageID(mid):
    for email in str(mid).split('\n'):
        if(email.isspace() or len(email) == 0 or email.find('@') < 0):
            continue
            
        email = email.strip()
        print(email)
        
        if(re.match(r"(.+)?<<(.+)@(.+)>>(.+)?", email)):
            email = email[email.find("<<")+1:email.rfind(">>")]
            print(0, email)
        
        if(re.match(r"(.+)?<(.+)@(.+)>(.+)?", email)):
            email = email[email.find("<")+1:email.rfind(">")]
            print(0, email)
            
        if(len(email) > 7):
            if(re.match("^.+@([?)[a-zA-Z0-9-.]+.([a-zA-Z]{2,3}|[0-9]{1,3})(]?))$", email) != None):
                return 0
            else:
                continue
        else:
            continue
        
    return 1

# %%
# Feature3 -> is the Message-Id column na or invalid ? 1->invalid, 0->valid
df_final['Feature3'] = 0
df_final['Feature3'] = df_final['Message-Id'].map(isValidMessageID)
df_final.loc[df_final['Message-Id'].isna(),'Feature3'] = 1
df_final.loc[df_final['Feature3'] == 1][['Feature3','Message-Id']]
# Out:
# <659888169528.7523837031@clubcaddie.com>
# 0 659888169528.7523837031@clubcaddie.com
# <454fac01c7807b$3709a460$7800010a@colo1.ad.shareholder.com>
# 0 454fac01c7807b$3709a460$7800010a@colo1.ad.shareholder.com
# <4E321B22388A375.BD82EB9DA5@verizon.net>
# 0 4E321B22388A375.BD82EB9DA5@verizon.net
# <31086b240706111747r1f56a5f4ta7b66a62fb093e20@mail.gmail.com>
# 0 31086b240706111747r1f56a5f4ta7b66a62fb093e20@mail.gmail.com
# <20070427-11956.42652.qmail@cpe-075-180-223-133.ec.res.rr.com>
# 0 20070427-11956.42652.qmail@cpe-075-180-223-133.ec.res.rr.com
# <E1HcQeP-0007UW-6G@server.fastbox.info>
# 0 E1HcQeP-0007UW-6G@server.fastbox.info
# <000a01c789a0$1eb68800$4e3d1941@kathy>
# 0 000a01c789a0$1eb68800$4e3d1941@kathy
# <F935A433.7809216C@tcjewelers.com>
# 0 F935A433.7809216C@tcjewelers.com
# <D45546375992BF429A93F7203358F14405DE82CD@sirius.fccc.edu>
# 0 D45546375992BF429A93F7203358F14405DE82CD@sirius.fccc.edu
# <000001c7a176$fdd29e00$0100007f@localhost>
# 0 000001c7a176$fdd29e00$0100007f@localhost
# <20070421212931.DDCDD162B01@lists.samba.org>
# 0 20070421212931.DDCDD162B01@lists.samba.org
# <46696167-qjgbd5rld@eatablinter.com>
# 0 46696167-qjgbd5rld@eatablinter.com
# <4642CE80.4030000@bitwrit.com.au>
# 0 4642CE80.4030000@bitwrit.com.au
# <6234869086.20070429063917@globalgw.com.au>
# 0 6234869086.20070429063917@globalgw.com.au
# <000001c79287$78e71980$0100007f@localhost>
# 0 000001c79287$78e71980$0100007f@localhost
# <01c7b066$fce11270$6c822ecf@corkysm>
# 0 01c7b066$fce11270$6c822ecf@corkysm
# <E1HcQbQ-0005ha-80@server.fastbox.info>
# 0 E1HcQbQ-0005ha-80@server.fastbox.info
# <000001c78409$ca7b5180$0100007f@localhost>
# 0 000001c78409$ca7b5180$0100007f@localhost
# <8975119BCD0AC5419D61A9CF1A923E9504F0D4F6@iahce2ksrv1.iah.bbsrc.ac.uk>
# 0 8975119BCD0AC5419D61A9CF1A923E9504F0D4F6@iahce2ksrv1.iah.bbsrc.ac.uk
# <3041.66.167.102.28.1178948153.squirrel@66.167.102.28>
# 0 3041.66.167.102.28.1178948153.squirrel@66.167.102.28
# <001601c77a62$159ddf40$064be5dc@computador>
# 0 001601c77a62$159ddf40$064be5dc@computador
# <703F1D12AEDA635.E5EA003B92@wanadoo.fr>
# 0 703F1D12AEDA635.E5EA003B92@wanadoo.fr
# <eb97335b0706081145l3a5b17fch187ce14ec5618212@mail.gmail.com>
# 0 eb97335b0706081145l3a5b17fch187ce14ec5618212@mail.gmail.com
# <200707011005.l61A5HL9031746@flax9.uwaterloo.ca>
# 0 200707011005.l61A5HL9031746@flax9.uwaterloo.ca
# <000b01c78269$a300bce0$00000000@NEO>
# 0 000b01c78269$a300bce0$00000000@NEO
# <LYRIS-5491332-9382899-2007.04.21-00.00.05--ktwarwic#speedy.uwaterloo.ca@lists.lexico.com>
# 0 E1Hirr5-00044u-U4@intern.SerNet.DE
# <20070627091756.833E9162BBC@lists.samba.org>
# 0 20070627091756.833E9162BBC@lists.samba.org
# <200704101234.l3ACYqWC000376@server2.madvlad.com>
# 0 200704101234.l3ACYqWC000376@server2.madvlad.com
# <xkisztNUEOIgnitpick@speedy.uwaterloo.ca>
# 0 xkisztNUEOIgnitpick@speedy.uwaterloo.ca
# <200707041116.47052.chromatic@wgz.org>
# 0 200707041116.47052.chromatic@wgz.org
# <01c785eb$cf6aa4f0$6c822ecf@paraphernaliatemblors>
# 0 01c785eb$cf6aa4f0$6c822ecf@paraphernaliatemblors
# <20070530145426.C8110162BC1@lists.samba.org>
# 0 20070530145426.C8110162BC1@lists.samba.org
# <6.6.8.3.5.31873265857772.086a8938@129.97.186.80>
# 0 6.6.8.3.5.31873265857772.086a8938@129.97.186.80
# <726056470.79149919036580@msn.com>
# 0 726056470.79149919036580@msn.com
# <46525C51.1000505@DonHopkins.com>
# 0 46525C51.1000505@DonHopkins.com
# <01c7bc4d$2b857a20$9bbfb08e@info>
# 0 01c7bc4d$2b857a20$9bbfb08e@info
# <01c7907c$f1135930$6c822ecf@billing>
# 0 01c7907c$f1135930$6c822ecf@billing
# <f4fffb01c7b276$bb467370$7800010a@colo1.ad.shareholder.com>
# 0 f4fffb01c7b276$bb467370$7800010a@colo1.ad.shareholder.com
# <E1HcQcS-0006Jc-IF@server.fastbox.info>
# 0 E1HcQcS-0006Jc-IF@server.fastbox.info
# <D2DE8C70CA26DA429514E2332200F44167E08C@mail_02.multiplan.com>
# 0 D2DE8C70CA26DA429514E2332200F44167E08C@mail_02.multiplan.com
# <000801c7b96c$56031e80$13c58c55@spieal>
# 0 000801c7b96c$56031e80$13c58c55@spieal
# <000001c7b547$d7224000$0100007f@dell-jq0lw09hdw>
# 0 000001c7b547$d7224000$0100007f@dell-jq0lw09hdw
# <Pine.LNX.4.64.0706170014080.4751@mylaptop>
# 0 Pine.LNX.4.64.0706170014080.4751@mylaptop
# <000001c7839c$d41aa000$d79ae6c9@pc-dani>
# 0 000001c7839c$d41aa000$d79ae6c9@pc-dani
# <20070428022704.61e91706.frx@firenze.linux.it>
# 0 20070428022704.61e91706.frx@firenze.linux.it
# <27f401c7a1c6$b51c3e1d$07400ec0@terra.com.sv>
# 0 27f401c7a1c6$b51c3e1d$07400ec0@terra.com.sv
# <01c77ea1$50d354d0$6c822ecf@fleny>
# 0 01c77ea1$50d354d0$6c822ecf@fleny
# <ef30550b0706161211s513c3de3r7682ae278cd6e1ca@mail.gmail.com>
# 0 ef30550b0706161211s513c3de3r7682ae278cd6e1ca@mail.gmail.com
# <000001c785a3$83c15f00$0100007f@localhost>
# 0 000001c785a3$83c15f00$0100007f@localhost
# <200704261606.l3QG6n6w014256@speedy.uwaterloo.ca>
# 0 200704261606.l3QG6n6w014256@speedy.uwaterloo.ca
# <822301c77bc5$16c1f337$c9e45e03@hexi.de>
# 0 822301c77bc5$16c1f337$c9e45e03@hexi.de
# <200706210913.l5L9DTbT007884@plg2.math.uwaterloo.ca>
# 0 200706210913.l5L9DTbT007884@plg2.math.uwaterloo.ca
# <000001c79546$a6adb600$0100007f@localhost>
# 0 000001c79546$a6adb600$0100007f@localhost
# <200705161249.l4GCnePU006676@mail111.netcontentinc.net>
# 0 200705161249.l4GCnePU006676@mail111.netcontentinc.net
# <01c77a2f$a7ea24e0$6c822ecf@fr>
# 0 01c77a2f$a7ea24e0$6c822ecf@fr
# <000001c7b289$b88f2100$0100007f@localhost>
# 0 000001c7b289$b88f2100$0100007f@localhost
# <200706261359.l5QDxgLA011682@flax9.uwaterloo.ca>
# 0 200706261359.l5QDxgLA011682@flax9.uwaterloo.ca
# <869192997.77604710164131@phentermine.com>
# 0 869192997.77604710164131@phentermine.com
# <3bdc01c78e9b$874336ff$b047a660@freemail.it>
# 0 3bdc01c78e9b$874336ff$b047a660@freemail.it
# <01c79926$0ccfa410$6c822ecf@informationservices>
# 0 01c79926$0ccfa410$6c822ecf@informationservices
# <0287161332.20070509044006@gotransit.ca>
# 0 0287161332.20070509044006@gotransit.ca
# <01c780f6$aac536f0$6c822ecf@dismissesIsolde's>
# 0 01c780f6$aac536f0$6c822ecf@dismissesIsolde's
# <E1Hj4lY-0007iT-0K@server.sanserver.info>
# 0 E1Hj4lY-0007iT-0K@server.sanserver.info
# <000401c79357$9afe66b0$6401a8c0@DDV3JY61>
# 0 000401c79357$9afe66b0$6401a8c0@DDV3JY61
#       Feature3                                         Message-Id
# 0            1                              <31867701_67397293>\n
# 1            1                              <36424144_99983662>\n
# 2            1                                               <>\n
# 5            1                          <199803250408.UAA03361>\n
# 8            1                           Mach10 1.1 fxpromo.com\n
# 21           1                            <tryitbeforeyoubuyit>\n
# 31           1                            199803272113.OOB5051@\n
# 32           1                                                NaN
# 34           1                                                NaN
# 35           1                                               <>\n
# 61           1           <01c7942a$a1633840$6c822ecf@a_pontius>\n
# 184          1      <01c7b8cc$69a4b6b0$bf228fdc@phillipe_patek>\n
# 193          1            <01c7867d$bc9788b0$6c822ecf@a_mystic>\n
# 219          1                 <01c7beda$59d2e590$6c822ecf@clt>\n
# 233          1                 <01c78e60$5b9deeb0$6c822ecf@djk>\n
# 242          1    <000801c791ca$788b87e0$16b2a8c0@Pedro_Afonso>\n
# 268          1            <01c78851$70ed0ae0$6c822ecf@a_potts2>\n
# 270          1             <01c78a35$0813e5d0$6c822ecf@a_ragan>\n
# 318          1           <01c7b3c3$b4ea3130$6c822ecf@a_raciti1>\n
# 322          1                <20070416020453.155047.qmail@ata>\n
# 330          1                 <01c78646$6c63a1d0$6c822ecf@ugo>\n
# 408          1             <000b01c78269$a300bce0$00000000@NEO>\n
# 424          1   <000001c7b5ad$12a32580$0100007f@miranda-07796...
# 440          1            <01c781bf$3ddae200$6c822ecf@a_rohani>\n
# 459          1             <001701c77de7$e3a30ea0$069b8b0c@mic>\n
# 463          1   <001201c7b915$e02f5a80$00977bd4@9cc6a1a81e6a4...
# 468          1    <01c7ac57$229b6510$6c822ecf@buffoonery'swept>\n
# 474          1          <017b01c7a1ff$89546390$4ba65c90@vv507j>\n
# 501          1              <000001c78ddf$5ebcbf80$bd8f245a@pc>\n
# 510          1             <001901c7b6e4$fa7663d0$00a72464@ali>\n
# ...        ...                                                ...
# 4234         1                                       <@msn.com>\n
# 4244         1          <01c7b9a5$ffdc2b70$6c822ecf@a_santiago>\n
# 4257         1             <001d01c77e15$cbe78830$89d1687e@zzp>\n
# 4274         1   <001101c77be5$7ddc1110$002f81e4@casa0l7gxk338...
# 4279         1       <01c78dc9$e6674920$6c822ecf@a_p.hayden_tj>\n
# 4358         1   <001201c785de$e72bf4c0$067c21d4@TYT5VNTH1A4H9...
# 4445         1   <001601c7a9f4$efdcae40$00696e24@usuario0da061...
# 4474         1              <001101c791b6$2c063c30$053470c4@hp>\n
# 4484         1             <01c79f64$ca929ae0$6c822ecf@a_pratt>\n
# 4497         1                 <01c7bc1e$841dba50$9fd9a4bd@ves>\n
# 4510         1      <20070410053939.3798.qmail@ditt-17dc15ce5b>\n
# 4522         1   <01c78f29$bee7ec90$6c822ecf@stag'scustomarily>\n
# 4539         1   <000e01c784c8$95e1fe50$001900c4@zyjdltnbaf0b2...
# 4551         1   <001501c7b17f$adb63170$001af7f4@usuario8908f5...
# 4569         1           <01c7982f$e5355130$6c822ecf@a_repetto>\n
# 4573         1           <01c7bb78$6f0bea70$6eeb18c9@dentosa_v>\n
# 4606         1                 <01c77b96$26b5fbc0$6c822ecf@jit>\n
# 4630         1   <01c7a9be$50317f50$6c822ecf@devilishlyslush's>\n
# 4641         1   <7406401ED5C7CD42B1A5DDCDA4D02271049A5F@BBY1E...
# 4688         1          <01c77cfa$82e20ff0$6c822ecf@a_rezavidi>\n
# 4695         1   <01c7b141$5ba74d30$6c822ecf@conveyor'sbunkers>\n
# 4749         1             <000f01c77c10$7824b120$0681ef1c@CCW>\n
# 4792         1   <001801c7810a$6fc891a0$059eb4bc@wagner2ds5hp1...
# 4853         1             <001b01c79ecf$a627e600$0019fb74@lee>\n
# 4871         1   <001101c77dd0$24e5d4a0$0140fdbc@zanresdp5vbf6...
# 4881         1   <001101c77dae$11414460$00d55294@labz9ozqrybi0...
# 4987         1   <000001c7b348$84c70080$0100007f@Master_Blaste...
# 5014         1   <D2DE8C70CA26DA429514E2332200F44167E08C@mail_...
# 5029         1                  <01c77a2f$a7ea24e0$6c822ecf@fr>\n
# 5036         1   <01c780f6$aac536f0$6c822ecf@dismissesIsolde's>\n
#
# [203 rows x 2 columns]

# %%
# Feature4, is the X-UIDL header not empty or na ? 1->not empty, 0->empty 
df_final['Feature4'] = 0
df_final.loc[df_final['X-UIDL'].notna(), 'Feature4'] = 1
df_final.loc[df_final['X-UIDL'].isna(), 'Feature4'] = 0
df_final.loc[df_final['Feature4']==1]['X-UIDL']
# Out:
# 0                   10293287_192832.222\n
# 1                   20720340_201230.501\n
# 7      c89dd4e061ba173523703cf25c3133a2\n
# 10     2610431056a78aeb1b128fda426c9a5e\n
# 12     33587715159195856343749765328732\n
# 13     2610431056a78aeb1b128fda426c9a5e\n
# 14                      123456789012376\n
# 18     f2c3e4bf7654f32bfd17a6c54dc32f1d\n
# 21     11111111111111111111111111111111\n
# 25     763cf6e5123c1287a83f12d7e99c60c9\n
# 31                        870483442.265\n
# Name: X-UIDL, dtype: object

# %%
s = df_final[df_final['Spam'] == 'Ham']['Feature2']
s0 = s[s == 0]
s1 = s[s == 1]
print('Ham', 'Valid To field', s0.count())
print('Ham', 'InValid To field', s1.count())

s = df_final[df_final['Spam'] == 'Spam']['Feature2']
s0 = s[s == 0]
s1 = s[s == 1]
print('Spam', 'Valid To field', s0.count())
print('Spam', 'InValid To field', s1.count())
# Out:
# Ham Valid To field 1350
# Ham InValid To field 46
# Spam Valid To field 3497
# Spam InValid To field 146

# %%
s = df_final[df_final['Spam'] == 'Ham']['Feature3']
s0 = s[s == 0]
s1 = s[s == 1]
print('Ham', 'Valid Message-Id field', s0.count())
print('Ham', 'InValid Message-Id field', s1.count())

s = df_final[df_final['Spam'] == 'Spam']['Feature3']
s0 = s[s == 0]
s1 = s[s == 1]
print('Spam', 'Valid Message-Id field', s0.count())
print('Spam', 'InValid Message-Id field', s1.count())
# Out:
# Ham Valid Message-Id field 1349
# Ham InValid Message-Id field 47
# Spam Valid Message-Id field 3487
# Spam InValid Message-Id field 156

# %%
s = df_final[df_final['Spam'] == 'Ham']['Feature4']
s0 = s[s == 0]
s1 = s[s == 1]
print('Ham', 'empty X-UIDL field', s0.count())
print('Ham', 'Not empty X-UIDL field', s1.count())

s = df_final[df_final['Spam'] == 'Spam']['Feature4']
s0 = s[s == 0]
s1 = s[s == 1]
print('Spam', 'Empty X-UIDL field', s0.count())
print('Spam', 'Not empty X-UIDL field', s1.count())
# Out:
# Ham empty X-UIDL field 1396
# Ham Not empty X-UIDL field 0
# Spam Empty X-UIDL field 3632
# Spam Not empty X-UIDL field 11

# %%
s = df_final[df_final['Spam'] == 'Ham']['Feature1']
s0 = s[s == 0]
s1 = s[s == 1]
print('Ham', 'Different From and To', s0.count())
print('Ham', 'Same From and To', s1.count())

s = df_final[df_final['Spam'] == 'Spam']['Feature1']
s0 = s[s == 0]
s1 = s[s == 1]
print('Spam', 'Different From and To', s0.count())
print('Spam', 'Same From and To', s1.count())
# Out:
# Ham Different From and To 1396
# Ham Same From and To 0
# Spam Different From and To 3632
# Spam Same From and To 11

# %%
s = df_final[df_final['Feature2'] == 1]
s = s[s['Spam'] == 'Spam']['To']
s
# Out:
# 4        bguenter@gemprint.com \n\n     Is your site l...
# 28                                                    NaN
# 30       bruce.guenter@gemprint.com \n\n     Is your s...
# 38       bguenter@linus.vsource.com \n\n     Is your s...
# 108          "OtherRecipients of perl Ticket #43325": ;\n
# 139      "Speakup is a screen review system for Linux....
# 191      <producttestpanel@speedy.uwaterloo.ca>\nPrece...
# 197      ip-health@lists.essential.org\ncontent-transf...
# 201       avcooper@flax9.uwaterloo.ca\nPrecedence: list\n
# 242                                                   NaN
# 283                                                   NaN
# 304      <producttestpanel@speedy.uwaterloo.ca>\nPrece...
# 376                                                   NaN
# 465                            undisclosed-recipients:;\n
# 467      ip-health@lists.essential.org\ncontent-type: ...
# 474      "Speakup is a screen review system for Linux....
# 511                                                   NaN
# 536      <speakup@braille.uwo.ca>\nSent: Saturday, May...
# 546                            undisclosed-recipients:;\n
# 554      "Inman, Brant A.   M.D." <Inman.Brant@mayo.ed...
# 573                                                   NaN
# 664      "r-help@stat.math.ethz.ch" <r-help@stat.math....
# 665      avcooper@speedy.uwaterloo.ca\nPrecedence: list\n
# 676      <r-help@stat.math.ethz.ch>\nSent: Friday, May...
# 737      <speakup@braille.uwo.ca>\nSent: Monday, June ...
# 787      "Speakup is a screen review system for Linux....
# 791      <producttestpanel@speedy.uwaterloo.ca>\nPrece...
# 807                                                   NaN
# 825      producttestpanel@flax9.uwaterloo.ca\nx-<mailt...
# 937      avcooper@speedy.uwaterloo.ca\nPrecedence: list\n
#                               ...
# 4287                                                  NaN
# 4289     "Booman, M" <m.booman@path.umcg.nl>, r-help@s...
# 4322     ip-health@lists.essential.org\ncontent-transf...
# 4388     "General Copyright Discussions (questions, or...
# 4389                                                  NaN
# 4406         "OtherRecipients of perl Ticket #42919": ;\n
# 4424     "Speakup is a screen review system for Linux....
# 4461     <producttestpanel@speedy.uwaterloo.ca>\nPrece...
# 4464                                                  NaN
# 4465         "OtherRecipients of perl Ticket #38217": ;\n
# 4514     <producttestpanel@speedy.uwaterloo.ca>\nPrece...
# 4524                                                  NaN
# 4557                                                  NaN
# 4579                           undisclosed-recipients:;\n
# 4593     <r-help@stat.math.ethz.ch>\nSent: Friday, May...
# 4614     "Lucke, Joseph F" <Joseph.F.Lucke@uth.tmc.edu...
# 4615     <producttestpanel@speedy.uwaterloo.ca>\nPrece...
# 4635     r-help <r-help@stat.math.ethz.ch>\nOrganizati...
# 4655                           undisclosed-recipients:;\n
# 4697                                                  NaN
# 4706                                                  NaN
# 4789                                                  NaN
# 4839     <producttestpanel@speedy.uwaterloo.ca>\nPrece...
# 4845     ip-health@lists.essential.org\ncontent-transf...
# 4901         "OtherRecipients of perl Ticket #42897": ;\n
# 4910                                                  NaN
# 4931                           undisclosed-recipients:;\n
# 4994                                                  NaN
# 4999                                                  NaN
# 5015                                                  NaN
# Name: To, Length: 146, dtype: object

# %%
import findspark
findspark.init()
import pyspark
from pyspark.ml.feature import HashingTF, IDF, IDFModel, Tokenizer, RegexTokenizer, StopWordsRemover
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

# %%
# Now, we create a Spark, Pandas dataframe of features from df_final
# Features include TFIDF vector, vector of misspellings count per email, punctuation count per email

# %%
import re
# clean a string off punctuations and additional whitespace, new line characters.
def processString(body):
    body = body.replace("'", "")
    body = re.sub(r"[^\w\s]|_", " ", body)
    body = re.sub("[\s+]", " ", body)
    return body

# %%
df_final['Body']
# Out:
# 0       increase your sales    \n30% to 100%    \nacce...
# 1       hi,\nwould you like to earn an extra $700 a we...
# 2       do you love cars?\n\nwant your own business?\n...
# 3       hi,\n\nwhat's in it for you? \n\n*************...
# 4                                                     NaN
# 5       do you want life insurance from the best compa...
# 6       email marketing works!!\n\nbull's eye gold is ...
# 7       introducing one of the most valuable marketing...
# 8       "free download" push 1000's of potential buyes...
# 9       all of us are constantly bombarded by people h...
# 10      come and get a free gift at the grand opening ...
# 11      hello if this is a service you have no need fo...
# 12      aloha,\nhappy easter and thank you for opening...
# 13      come and get a free gift at the grand opening\...
# 14      greetings!\n\njoin the founding chairman/ceo o...
# 15      want to make money on the net?\n\nit's simple....
# 16      **** water is the most essential element for s...
# 17      trouble promoting your online venture?\n\njoin...
# 18      one million dollar bill free!\n\nbet you have ...
# 19      why would people want to pass up this extremel...
# 20      +-+-+-+-+-+-+-+-+-+   c h i n a   n e w s   d ...
# 21      ______________________________________________...
# 22      newark, nj (ip) -- finally there may be a reso...
# 23      email marketing works!!\n\nbull's eye gold is ...
# 24      baileyli@hubble.sheridanc.on.ca, baileym@conce...
# 25      earn $500.00 by noon tomorrow!\n\njust refer p...
# 26      is your web site the best kept secret on the i...
# 27      baileyli@hubble.sheridanc.on.ca, baileym@conce...
# 28      free download.register your web site to over 7...
# 29      is your web site the best kept secret on the i...
#                               ...
# 5009    i'm trying to set the tooltip of a tool item, ...
# 5010    opinion of our customers:\nmy order arrived wi...
# 5011    microsoft office 2007 enterprise=20=\n$79.95\n...
# 5012    satcon photovoltaic inverters installed at 1.1...
# 5013    mouvement desjardins\n\n\n\n\n \n\n\n\n\n\n\n\...
# 5014    can someone put me thru this?\n\nwhen i run th...
# 5015    hey sweetie, you wanna attract every chick at ...
# 5016    /9j/4aaqskzjrgabaqeayabgaad/2wbdaaggbgcgbqghbw...
# 5017    ok, i tried the update-rc.d route and ended up...
# 5018    r0lgodlhvge2afcaaaaaaiaaaacaaicaaaaagiaagacagi...
# 5019    on sat, 28 apr 2007 00:39:57 +0100 stephen gra...
# 5020    always be =\nready! \nif you have a problem ge...
# 5021    glad to see you!\nvisit our new online pharmac...
# 5022    tests=bayes_50,dkim_signed,dkim_verified,dk_po...
# 5023    r0lgodlhdqjhabmaapv7/n0ofwegkvoknzxxqp7nzfqlk1...
# 5024    r0lgodlhfgktafgsaageaaaa/////waaach5baqaabaala...
# 5025    don't let ed affect=\n your sex life!\nerectil...
# 5026    r0lgodlhlaf0aychaaajah8aaab/aheiaaachheadwojjm...
# 5027    r0lgodlhcaeqazeaapkebp///wqebp///yh5baeaaamala...
# 5028    campaign manager\n\n\n\n\n\n\n\n\n\noatt refor...
# 5029    good day!\nlook at the assortment of our new=2...
# 5030    /9j/4aaqskzjrgabagaazabkaad/7aarrhvja3kaaqaeaa...
# 5031    1:éìòµïúêû£¨¿éòôíøéï²é£©  2:»õîïí³ò»ïúêû   3:¹...
# 5032    quality and cheap viagra\n\n\n\ncheck it out, ...
# 5033    what is cialis?\ncialis is the only ed (erecti...
# 5034    can't find meds at your local drug store?\ntir...
# 5035    fda approved on-line pharmacies.click here\nch...
# 5036    worldwide lotto service!\nplay lotto around th...
# 5037    rbc\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 5038    > a <- earth(volume ~ ., data = trees)\n> summ...
# Name: Body, Length: 5039, dtype: object

# %%
# Feature 6 - TFIDF
body = df_final['Body']
body = body.map(processString, na_action='ignore')

# %%
pddf = pd.DataFrame(body, columns=['Body'])
pddf['RawFeature2'] = df_final['Feature2']
pddf['RawFeature3'] = df_final['Feature3']
pddf['RawFeature4'] = df_final['Feature4']
pddf['Spam'] = df_final['Spam']
pddf.head()
# Out:
#                                                 Body  RawFeature2  \
# 0  increase your sales     30  to 100      accept...            0
# 1  hi  would you like to earn an extra  700 a wee...            0
# 2  do you love cars   want your own business   th...            0
# 3  hi   whats in it for you                      ...            0
# 4                                                NaN            1
#
#    RawFeature3  RawFeature4  Spam
# 0            1            1  Spam
# 1            1            1  Spam
# 2            1            0  Spam
# 3            0            0  Spam
# 4            0            0  Spam

# %%
pddf.fillna("", inplace=True)
df = spark.createDataFrame(pddf)
df.show(3)
# Out:
# +--------------------+-----------+-----------+-----------+----+
# |                Body|RawFeature2|RawFeature3|RawFeature4|Spam|
# +--------------------+-----------+-----------+-----------+----+
# |increase your sal...|          0|          1|          1|Spam|
# |hi  would you lik...|          0|          1|          1|Spam|
# |do you love cars ...|          0|          1|          0|Spam|
# +--------------------+-----------+-----------+-----------+----+
# only showing top 3 rows

# %%
from pyspark.ml.feature import StringIndexer
stringIndexer = StringIndexer(inputCol='Spam', outputCol='label')
df = stringIndexer.fit(df).transform(df)
df.show(3)
# Out:
# +--------------------+-----------+-----------+-----------+----+-----+
# |                Body|RawFeature2|RawFeature3|RawFeature4|Spam|label|
# +--------------------+-----------+-----------+-----------+----+-----+
# |increase your sal...|          0|          1|          1|Spam|  0.0|
# |hi  would you lik...|          0|          1|          1|Spam|  0.0|
# |do you love cars ...|          0|          1|          0|Spam|  0.0|
# +--------------------+-----------+-----------+-----------+----+-----+
# only showing top 3 rows

# %%
regexTokenizer = RegexTokenizer(inputCol='Body', outputCol='Body_Tokens', pattern='\\W')

# %%
df_tokenized = regexTokenizer.transform(df)
df_tokenized['Body_Tokens']
# Out:
# Column<b'Body_Tokens'>

# %%
df_tokenized.show(3)
# Out:
# +--------------------+-----------+-----------+-----------+----+-----+--------------------+
# |                Body|RawFeature2|RawFeature3|RawFeature4|Spam|label|         Body_Tokens|
# +--------------------+-----------+-----------+-----------+----+-----+--------------------+
# |increase your sal...|          0|          1|          1|Spam|  0.0|[increase, your, ...|
# |hi  would you lik...|          0|          1|          1|Spam|  0.0|[hi, would, you, ...|
# |do you love cars ...|          0|          1|          0|Spam|  0.0|[do, you, love, c...|
# +--------------------+-----------+-----------+-----------+----+-----+--------------------+
# only showing top 3 rows

# %%
stopWordsRemover = StopWordsRemover(inputCol="Body_Tokens", outputCol="Body_Tokens2")
df_tokenized = stopWordsRemover.transform(df_tokenized)
df_tokenized.show(5)
# Out:
# +--------------------+-----------+-----------+-----------+----+-----+--------------------+--------------------+
# |                Body|RawFeature2|RawFeature3|RawFeature4|Spam|label|         Body_Tokens|        Body_Tokens2|
# +--------------------+-----------+-----------+-----------+----+-----+--------------------+--------------------+
# |increase your sal...|          0|          1|          1|Spam|  0.0|[increase, your, ...|[increase, sales,...|
# |hi  would you lik...|          0|          1|          1|Spam|  0.0|[hi, would, you, ...|[hi, like, earn, ...|
# |do you love cars ...|          0|          1|          0|Spam|  0.0|[do, you, love, c...|[love, cars, want...|
# |hi   whats in it ...|          0|          0|          0|Spam|  0.0|[hi, whats, in, i...|[hi, whats, stick...|
# |                    |          1|          0|          0|Spam|  0.0|                  []|                  []|
# +--------------------+-----------+-----------+-----------+----+-----+--------------------+--------------------+
# only showing top 5 rows

# %%
df_final.shape
# Out:
# (5039, 12)

# %%
df_tokenized.count()
# Out:
# 5039

# %%
dir(df_tokenized)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_collectAsArrow',
#  '_jcols',
#  '_jdf',
#  '_jmap',
#  '_jseq',
#  '_lazy_rdd',
#  '_sc',
#  '_schema',
#  '_sort_cols',
#  'agg',
#  'alias',
#  'approxQuantile',
#  'cache',
#  'checkpoint',
#  'coalesce',
#  'colRegex',
#  'collect',
#  'columns',
#  'corr',
#  'count',
#  'cov',
#  'createGlobalTempView',
#  'createOrReplaceGlobalTempView',
#  'createOrReplaceTempView',
#  'createTempView',
#  'crossJoin',
#  'crosstab',
#  'cube',
#  'describe',
#  'distinct',
#  'drop',
#  'dropDuplicates',
#  'drop_duplicates',
#  'dropna',
#  'dtypes',
#  'explain',
#  'fillna',
#  'filter',
#  'first',
#  'foreach',
#  'foreachPartition',
#  'freqItems',
#  'groupBy',
#  'groupby',
#  'head',
#  'hint',
#  'intersect',
#  'isLocal',
#  'isStreaming',
#  'is_cached',
#  'join',
#  'limit',
#  'localCheckpoint',
#  'na',
#  'orderBy',
#  'persist',
#  'printSchema',
#  'randomSplit',
#  'rdd',
#  'registerTempTable',
#  'repartition',
#  'replace',
#  'rollup',
#  'sample',
#  'sampleBy',
#  'schema',
#  'select',
#  'selectExpr',
#  'show',
#  'sort',
#  'sortWithinPartitions',
#  'sql_ctx',
#  'stat',
#  'storageLevel',
#  'subtract',
#  'summary',
#  'take',
#  'toDF',
#  'toJSON',
#  'toLocalIterator',
#  'toPandas',
#  'union',
#  'unionAll',
#  'unionByName',
#  'unpersist',
#  'where',
#  'withColumn',
#  'withColumnRenamed',
#  'withWatermark',
#  'write',
#  'writeStream']

# %%
hashingTF = HashingTF(inputCol="Body_Tokens2", outputCol="TermFreqs", numFeatures=20)
df3 = hashingTF.transform(df_tokenized)

# %%
df3.columns
# Out:
# ['Body',
#  'RawFeature2',
#  'RawFeature3',
#  'RawFeature4',
#  'Spam',
#  'label',
#  'Body_Tokens',
#  'Body_Tokens2',
#  'TermFreqs']

# %%
idfModel = IDF(inputCol="TermFreqs", outputCol="RawFeature1").fit(df3)
df4 = idfModel.transform(df3)
df4.show(5)
# Out:
# +--------------------+-----------+-----------+-----------+----+-----+--------------------+--------------------+--------------------+--------------------+
# |                Body|RawFeature2|RawFeature3|RawFeature4|Spam|label|         Body_Tokens|        Body_Tokens2|           TermFreqs|         RawFeature1|
# +--------------------+-----------+-----------+-----------+----+-----+--------------------+--------------------+--------------------+--------------------+
# |increase your sal...|          0|          1|          1|Spam|  0.0|[increase, your, ...|[increase, sales,...|(20,[0,1,2,3,4,5,...|(20,[0,1,2,3,4,5,...|
# |hi  would you lik...|          0|          1|          1|Spam|  0.0|[hi, would, you, ...|[hi, like, earn, ...|(20,[0,1,2,3,4,5,...|(20,[0,1,2,3,4,5,...|
# |do you love cars ...|          0|          1|          0|Spam|  0.0|[do, you, love, c...|[love, cars, want...|(20,[0,1,2,3,4,5,...|(20,[0,1,2,3,4,5,...|
# |hi   whats in it ...|          0|          0|          0|Spam|  0.0|[hi, whats, in, i...|[hi, whats, stick...|(20,[0,1,2,3,4,5,...|(20,[0,1,2,3,4,5,...|
# |                    |          1|          0|          0|Spam|  0.0|                  []|                  []|          (20,[],[])|          (20,[],[])|
# +--------------------+-----------+-----------+-----------+----+-----+--------------------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %%
from pyspark.ml.feature import VectorAssembler
vectorAssembler = VectorAssembler(inputCols=['RawFeature1', 'RawFeature2', 'RawFeature3', 'RawFeature4'], outputCol='Features')

# %%
df5 = vectorAssembler.transform(df4)
df5.show(2)
# Out:
# +--------------------+-----------+-----------+-----------+----+-----+--------------------+--------------------+--------------------+--------------------+--------------------+
# |                Body|RawFeature2|RawFeature3|RawFeature4|Spam|label|         Body_Tokens|        Body_Tokens2|           TermFreqs|         RawFeature1|            Features|
# +--------------------+-----------+-----------+-----------+----+-----+--------------------+--------------------+--------------------+--------------------+--------------------+
# |increase your sal...|          0|          1|          1|Spam|  0.0|[increase, your, ...|[increase, sales,...|(20,[0,1,2,3,4,5,...|(20,[0,1,2,3,4,5,...|[2.20922967993915...|
# |hi  would you lik...|          0|          1|          1|Spam|  0.0|[hi, would, you, ...|[hi, like, earn, ...|(20,[0,1,2,3,4,5,...|(20,[0,1,2,3,4,5,...|[7.59422702479084...|
# +--------------------+-----------+-----------+-----------+----+-----+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 2 rows

# %%
# Keeping only columns that we need
df6 = df5.drop('Body', 'RawFeature2', 'RawFeature3','RawFeature4','Body_Tokens','Body_Tokens2','TermFreqs','RawFeature1')
df6.columns
# Out:
# ['Spam', 'label', 'Features']

# %%
df5.columns
# Out:
# ['Body',
#  'RawFeature2',
#  'RawFeature3',
#  'RawFeature4',
#  'Spam',
#  'label',
#  'Body_Tokens',
#  'Body_Tokens2',
#  'TermFreqs',
#  'RawFeature1',
#  'Features']

# %%
df6_train, df6_test = df6.randomSplit([3.0, 1.0], 24)

# %%
from pyspark.ml.classification import NaiveBayes

# %%
nb = NaiveBayes(smoothing=1.0, modelType='multinomial', featuresCol='Features')

# %%
NBModel = nb.fit(df6_train)

# %%
predictions = NBModel.transform(df6_test)

# %%
correct = predictions[predictions['label'] == predictions['prediction']]
incorrect = predictions[predictions['label'] != predictions['prediction']]

# %%
print(correct.count(), incorrect.count())
# Out:
# 877 342

# %%
print('Total time in seconds', time() - starttime)
# Out:
# Total time in seconds 336.84897232055664

# %%
isinstance(df_final, pd.DataFrame)
# Out:
# True

# %% [markdown]
# ## Feature 5 Engineering -> Percent Misspellings

# %%
df_tokenized = df_tokenized.sample(0.005)
df_tokenized.show()

# %%
df_tokenized.count()

# %%
# Feature5 -> Percent of misspellings in mail body
from pattern.en import spelling
spelling.suggest('wrng')

# %%
from functools import reduce
from pattern.en import spelling
percentSpelling = []
def getPercentMisspelled(wordList):
    print(wordList)
    f = lambda x,y: int(x)+1 if spelling.suggest(y)[0][0] != y else int(x)
    e = float(reduce(f, wordList, 0)/len(wordList))
    percentSpelling.append(e)

# %%
#r1 = df_tokenized.first()['Body2']

# %%
#getPercentMisspelled(r1)

# %%
df_tokenized

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import FloatType
#myudf = udf(getPercentMisspelled, FloatType())

# %%
#c = myudf(df_tokenized.Body2)

# %%
#df_tokenized = df_tokenized.withColumn('Feature5', c)
