# %% [markdown]
# Our datasets are unstructured text files, that contain email headers, subject and body. In this part, we parse through the text files, convert into a structured pandas dataset, and save it as "structured.xlsx"

# %% [markdown]
# Execute the following cells only if running on Google Colab, to install the needed packages and download the datasets from Google drive.

# %%
# !pip install PyDrive
# !pip install XlsxWriter
# Out:
# Collecting PyDrive
#   Downloading https://files.pythonhosted.org/packages/52/e0/0e64788e5dd58ce2d6934549676243dc69d982f198524be9b99e9c2a4fd5/PyDrive-1.3.1.tar.gz (987kB)
#     100% |████████████████████████████████| 993kB 9.1MB/s
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (1.6.7)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (4.1.2)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from PyDrive) (3.13)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (1.11.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (3.0.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.11.3)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.4)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.2.2)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->PyDrive) (3.4.2)
# Building wheels for collected packages: PyDrive
# done
#   Stored in directory: /content/.cache/pip/wheels/fa/d2/9a/d3b6b506c2da98289e5d417215ce34b696db856643bad779f4
# Successfully built PyDrive
# Installing collected packages: PyDrive
# Successfully installed PyDrive-1.3.1
# Collecting XlsxWriter
#   Downloading https://files.pythonhosted.org/packages/33/50/136b801d106fcebb2428a764e5c599e020d8227a3623db078e05eb4793a5/XlsxWriter-1.0.5-py2.py3-none-any.whl (142kB)
#     100% |████████████████████████████████| 143kB 5.5MB/s
# Installing collected packages: XlsxWriter
# Successfully installed XlsxWriter-1.0.5

# %%
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %% [markdown]
# Authenticate PyDrive API to access Google drive

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# Now, we download and untar the two datasets, 1998 and trec07p, that we are going to work with.

# %%
download = drive.CreateFile({'id': '1QtoxpJmd1lys7c7LaYXiOjbzMdMOpeVX'})
download.GetContentFile('1998.tar')

# %%
download2 = drive.CreateFile({'id': '1xaJL1eoccrCyS45xgF23dVY_KCER-oAD'})
download2.GetContentFile('trec07p.tar')

# %%
# !tar xf 1998.tar
# !tar xf trec07p.tar

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
notHeaders = ['A',
 'A.normal2{color',
 'A.normal{color',
 'A.over{color',
 'ATT',
 'Action',
 'Added',
 'Address',
 'An',
 'Asunto',
 'Author',
 'Auto-Submitted',
 'BATCH',
 'Betreff',
 'Beurteilung',
 'Bookmark',
 'Brma',
 'BrmaSmtpAuthUser',
 'C',
 'Call',
 'Cancel-Lock',
 'Carlson',
 'Caveats',
 'Changeset',
 'Cia1iis',
 'Cited',
 'Classification',
 'Comment',
 'Company',
 'Complaints',
 'Congratulations',
 'Contact',
 'Copyright',
 'Corp.<http',
 'Corporation<http',
 'Credibility',
 'Date-warning',
 'Datum',
 'De',
 'Details',
 'De\xa0',
 'Diagnostic-Code',
 'Dinah',
 'Envoyé\xa0',
 'FATAL',
 'FDA',
 'FONT-SIZE',
 'Featuring',
 'Fixes',
 'Gesendet',
 'Hash',
 'Hinweis',
 'ISIN',
 'Importance',
 'Inc.<http',
 'Index',
 'Jabber-ID',
 'Jim',
 'John',
 'Kopia',
 'LINE-HEIGHT',
 'List-Help',
 'Log',
 'London',
 'Lookup',
 'MOTD',
 'Mail-Followup-To',
 'Managed-by',
 'Market',
 'Metze',
 'Modified',
 'NOTE',
 'Name',
 'Napster<http',
 'Newshawk',
 'Notice',
 'Number',
 'OTC',
 'Objet\xa0',
 'Old-Return-Path',
 'OpenPGP',
 'Organisation',
 'Organization',
 'PADDING-BOTTOM',
 'PHONE',
 'Package',
 'Page',
 'Para',
 'Phone',
 'Posted',
 'Precedence',
 'President',
 'Priority',
 'Products',
 'Pubdate',
 'Publicitate',
 'REF',
 'RT-Ticket',
 'Rangel',
 'Received-SPF',
 'References',
 'Reminder',
 'Removed',
 'Reporting-MTA',
 'S.umbol',
 'Sent',
 'Severity',
 'Site',
 'Skickat',
 'Source',
 'Spoken',
 'Sym8oL',
 'Symbol',
 'Sys.putenv("http_proxy"="http',
 'TELEPHONE',
 'Talk',
 'Tel',
 'Teste',
 'Ticker',
 'Till',
 'Timing',
 'Tname',
 'Try',
 'Type',
 'UEI',
 'URL',
 'Visit',
 'Von',
 'WASHINGTON',
 'WKN',
 'Webpage',
 'Website',
'A.RVTS2',
 'ASTIG',
 'AXIS',
 'Ambieen',
 'Anova',
 'Below',
 'CARGO',
 'CNN',
 'CNNMoney',
 'City',
 'Clinton',
 'Collins',
 'Given',
 'HEADLINES',
 'IRAN',
 'Iterations',
 'Juego!<o',
 'Kernel',
 'L<Parrot',
 'Parrot',
 'Price']

# %% [markdown]
# Since many email body fields contain HTML markup too, we define a method that filters out visible text from HTML content.

# %%
def parseTextFromHTML(body):
    body = body.lower()
    htmlstartindex = body.find('<html>')
    htmlendindex = body.find('</html>')
    
    #if(htmlstartindex == -1 or htmlendindex == -1):
        #return body
    
    htmlcontent = body#[htmlstartindex:htmlendindex+7]
    soup = BeautifulSoup(htmlcontent, 'html.parser')
    [s.extract() for s in soup(['style', 'script'])]
    return soup.getText().strip()
    #return body[:htmlstartindex] + soup.getText().strip() + body[htmlendindex+7:]

# %%
"""# parse the email file(spam or ham) to create a pandas dataframe
def getDFFromEmail(path, spam):
    l = []
    precurrkv = []
    sufcurrkv = []
    count = 0
    body = False
    try:
        stream = open(path, errors='strict', encoding='UTF-8')
        stream.readlines()
        stream.seek(0)
        print("Using UTF-8 encoding")
    except (Exception):
        print("Using ANSI encoding")
        stream = open(path, errors='strict', encoding='ANSI')
        stream.readlines()
        stream.seek(0)
        
    for line in stream:
        if(line.startswith('<DOCTYPE')):
            continue
            
        colonIndex = line.find(":")
        
        if(count > 15 and not body):
            body = True
            l.append(precurrkv)
            
        if(line[0].isupper() and line.find(' ',0,colonIndex)<0 and colonIndex >= 0 and colonIndex < 30 and not body 
           and line[:colonIndex] not in notHeaders):
            count = 0
            if(len(sufcurrkv) > 0 and len(precurrkv) > 0):
                precurrkv[1] = "".join((precurrkv[1], "".join(sufcurrkv)))
                l.append(precurrkv)
            elif(len(precurrkv) > 0):
                l.append(precurrkv)
            precurrkv = line.split(sep=":", maxsplit=1)
            sufcurrkv.clear()

        elif(str(line[0:2]).isspace() and not body):
            count += 1
            sufcurrkv.append(line)
        elif(str(line).startswith('>') and not body):
            body = True
            sufcurrkv = [''.join((':'.join(precurrkv), "".join(sufcurrkv)))]
        else:
            #count += 1
            sufcurrkv.append(line)

    l.append(["Body", parseTextFromHTML("".join(sufcurrkv))])
    l.append(["Spam", 'Spam' if spam else 'Ham'])
    l.append(["Tname", path])

    d = pd.DataFrame(np.array(l)).drop_duplicates(subset=0)
    return d    """
""""""
# Out:
# ''

# %% [markdown]
# We define a method that parses an email text file represented by the path parameter and returns a pandas dataframe.

# %%
# parse the email file(spam or ham) to create a pandas dataframe
from collections import deque
from codecs import open
def getDFFromEmail(path, spam):
    l = dict()
    precurrkv = []
    sufcurrkv = deque()
    count = 0
    body = False
        
    try:
        stream = open(path, errors='strict')
        stream.readlines()
        stream.seek(0)
        print("Using UTF-8 encoding")
    except (Exception):
        try:
            print("Using ISO-8859-1 encoding")
            stream = open(path, errors='strict', encoding='iso-8859-1')
            stream.readlines()
            stream.seek(0)
        except (Exception):
            return ""
        
    for line in stream:
        if(line.startswith('<DOCTYPE')):
            continue
            
        colonIndex = line.find(":")
        
        if(count > 15 and not body):
            body = True

            
        if(line[0].isupper() and line.find(' ',0,colonIndex)<0 and colonIndex >= 0 and colonIndex < 30 and not body 
           and line[:colonIndex] not in notHeaders):
            count = 0
            if(sufcurrkv and len(precurrkv) > 0):
                fieldname = sufcurrkv.popleft()
                l[fieldname] = [''.join(sufcurrkv)]
            
            precurrkv = line.split(sep=":", maxsplit=1)
            sufcurrkv.clear()
            sufcurrkv.extend(precurrkv)

        elif(str(line[0:2]).isspace() and not body):
            count += 1
            sufcurrkv.append(line)
        elif(str(line).startswith('>') and not body):
            body = True
            sufcurrkv.append(line)
        else:
            #count += 1
            sufcurrkv.append(line)

    fieldname = sufcurrkv.popleft()
    l[fieldname] = sufcurrkv.popleft()    
    l["Body"] = [parseTextFromHTML("".join(sufcurrkv))]
    l["Spam"] = ['Spam'] if spam else ['Ham']
    l["Tname"] = [path]

    d = pd.DataFrame(l)
    return d.T.reset_index()

# %% [markdown]
# We define a generator for the 1998 dataset that iterates over all email text files in a directory and yields resulting dataframes.

# %%
# iterate over all files in the directory to create the dataframes
def getAllDFFromDirectory(directorypath):
    for filename in os.listdir(directorypath):
        print("Getting DF for "+"".join((directorypath, filename)))
        if(filename.startswith("spm")):
            yield getDFFromEmail("".join((directorypath, filename)), True)
        elif(filename.count("msg") > 0):
            yield getDFFromEmail("".join((directorypath, filename)), False)
        else:
            yield getDFFromEmail("".join((directorypath, filename)), True)

# %%
from functools import reduce

# create dataframes from all directories from that contain spam or ham email text files

# %%
directorypath = "1998/1998/03/"
dfs = [i for i in getAllDFFromDirectory(directorypath) if(isinstance(i,pd.DataFrame))]
# Out:
# Getting DF for 1998/1998/03/891020025.3222.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891272355.532.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/890929482.24868.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891184729.10913.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891020032.3224.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/890929562.24883.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/890929468.24864.txt
# Using ISO-8859-1 encoding
# Getting DF for 1998/1998/03/890929499.24873.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/890929485.24869.txt
# Using ISO-8859-1 encoding
# Getting DF for 1998/1998/03/891285049.11748.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891219144.5405.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891020028.3223.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891219152.5407.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891285044.11747.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891219148.5406.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891219203.5423.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891219215.5425.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/890956849.27937.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891020045.3228.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891219139.5404.txt
# Using ISO-8859-1 encoding
# Getting DF for 1998/1998/03/891275686.11191.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891219128.5403.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891275675.11190.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/890929475.24866.txt
# Using ISO-8859-1 encoding
# Getting DF for 1998/1998/03/890929492.24871.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/890929566.24884.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891020042.3227.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/890929496.24872.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/890929479.24867.txt
# Using ISO-8859-1 encoding
# Getting DF for 1998/1998/03/891002827.28090.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891020035.3225.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891219156.5408.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/890929572.24886.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/890929489.24870.txt
# Using ISO-8859-1 encoding
# Getting DF for 1998/1998/03/891219210.5424.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/890929472.24865.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/890929569.24885.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891219236.5426.txt
# Using UTF-8 encoding
# Getting DF for 1998/1998/03/891020038.3226.txt
# Using UTF-8 encoding

# %% [markdown]
# We define a generator for the trec07p dataset that iterates over all email text files in a directory and yields dataframes.

# %%
# iterate over all files in the directory to create the dataframes
def getAllDFFromDirectory2(directorypath, target):
    for i,filename in enumerate(os.listdir(directorypath)[:5000]):
        print("Getting DF for "+"".join((directorypath, filename)))
        
        if(target[i] == 'spam'):
            yield getDFFromEmail("".join((directorypath, filename)), True)
        else:
            yield getDFFromEmail("".join((directorypath, filename)), False)

# %%
def getTrec07Target():
    for line in open("trec07p/trec07p/full/index"):
        yield line.split(" ")[0]

target = [i for i in getTrec07Target()]
print(len(target))

directorypath = "trec07p/trec07p/data/"
dfs2 = [i for i in getAllDFFromDirectory2(directorypath, target) if(isinstance(i,pd.DataFrame))]
# Out:
# 75419
# Getting DF for trec07p/trec07p/data/inmail.71535
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.33277
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.10451
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.50259
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.69434
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.44359
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.70925
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.53784
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.1906
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.13040
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.70343
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.69929
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.36598
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.22420
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.52705
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.55160
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.59950
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.41605
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.6769
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.15423
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.32133
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.40255
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.34273
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.49021
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.1056
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.30776
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.53474
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.10637
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.12210
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.8726
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.69394
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.52794
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.27142
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.72842
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.24722
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.54822
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.61052
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.18339
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.32508
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.50596
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.34214
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.32604
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.32840
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.46219
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.23013
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.52377
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.14598
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.18999
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.71450
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.11231
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.43572
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.73960
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.70523
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.42150
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.42365
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.10860
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.6285
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.5569
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.36892
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.34264
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.60503
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.68255
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.29893
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.26967
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.1465
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.59338
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.30356
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.12269
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.52837
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.66889
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.20199
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.66320
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.69320
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.21862
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.57185
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.48289
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.43551
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.52697
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.56797
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.70321
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.23238
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.41955
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.74547
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.37243
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.28811
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.48950
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.1804
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.7581
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.15723
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.32792
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.45649
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.22407
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.47997
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.3448
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.33086
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.28203
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.72207
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.51059
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.44956
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.13847
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.46533
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.48853
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.31642
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.61028
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.29299
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.62808
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.47015
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.4073
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.58609
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.68170
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.29089
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.66830
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.62656
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.64887
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.12090
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.60108
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.12788
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.51673
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.21691
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.38372
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.1652
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.28172
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.49735
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.2239
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.71458
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.58068
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.37021
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.23349
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.41159
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.19186
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.67936
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.65621
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.13689
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.72962
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.59304
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.72531
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.44233
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.12377
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.63383
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.9902
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.278
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.37847
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.63826
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.8664
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.35998
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.67392
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.34084
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.590
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.3099
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.39926
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.38263
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.21661
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.15938
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.68791
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.18825
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.28315
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.17344
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.63798
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.26768
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.71936
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.74278
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.18287
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.26626
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.58741
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.72118
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.21655
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.30837
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.12307
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.63214
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.28731
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.57316
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.6134
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.38758
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.28337
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.2080
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.64274
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.58921
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.29230
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.3399
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.34430
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.74396
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.51915
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.5577
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.28104
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.46853
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.52999
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.41113
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.60959
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.40756
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.9978
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.32232
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.8936
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.37441
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.26827
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.26280
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.74145
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.55145
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.63778
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.60808
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.31824
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.54031
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.62926
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.3916
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.9852
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.44600
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.8838
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.38791
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.2836
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.74297
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.65095
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.47076
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.61455
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.52322
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.24606
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.72371
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.72290
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.5154
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.30220
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.71489
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.11880
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.67717
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.19127
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.18241
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.11074
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.26438
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.67080
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.1711
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.11759
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.73971
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.18155
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.46921
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.63702
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.66893
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.41233
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.71454
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.30364
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.60581
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.7399
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.61644
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.68299
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.63652
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.59199
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.15385
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.23029
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.45875
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.8579
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.58941
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.17567
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.21281
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.2319
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.62119
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.35161
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.37623
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.190
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.60684
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.66332
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.74940
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.28943
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.38958
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.31999
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.11309
# Using UTF-8 encoding
# Getting DF for trec07p/trec07p/data/inmail.26527
# Using ISO-8859-1 encoding
# Getting DF for trec07p/trec07p/data/inmail.33651
# Using UTF-8 encoding

# %%
# Test for number of columns in dataframes
#dfs2.map(lambda df: df.shape[0])
#[i for i in zip(map(lambda df: df.shape[0],dfs2), range(len(dfs2))) if(i[0]>40)]

# %% [markdown]
# Use functools.reduce to merge all resulting dataframes into a single dataframe representing all emails.

# %%
df_final = reduce(lambda left,right: pd.merge(left,right,how='outer',on='index'), dfs+dfs2)

# %%
df_final = df_final.set_index('index').T

# %%
df_final['index'] = [i for i in range(df_final.shape[0])]
df_final.set_index('index', inplace=True)

# %%
df_final.head()
# Out:
# index                                               Body  \
# index
# 0      increase your sales    \n30% to 100%    \nacce...
# 1      hi,\nwould you like to earn an extra $700 a we...
# 2      do you love cars?\n\nwant your own business?\n...
# 3      hi,\n\nwhat's in it for you? \n\n*************...
# 4
#
# index                                           Comments  \
# index
# 0         Authenticated Sender is <user122@whynot.net>\n
# 1       Authenticated Sender is <cm_offer@earthling.n...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#
# index                                      Date               Delivered-To  \
# index
# 0       Sat, 21 Mar 1998 23:20:27 -0600 (CST)\n   bguenter@hal.qcc.sk.ca\n
# 1       Mon, 30 Mar 1998 00:43:57 -0500 (EST)\n         bruceg@qcc.sk.ca\n
# 2                 Thu, 19 Feb 98 17:31:31 EST\n   bait@mikhail.qcc.sk.ca\n
# 3           \tSat, 28 Mar 98 17:07:45 PST8PDT\n         bruceg@qcc.sk.ca\n
# 4             Thu, 26 Mar 1998 21:47:54 -0500\n   bguenter@hal.qcc.sk.ca\n
#
# index                       From                                   Message-Id  \
# index
# 0        islander622@yahoo.com\n                        <31867701_67397293>\n
# 1       cm_offer@earthling.net\n                        <36424144_99983662>\n
# 2          carlover@goplay.com\n                                          NaN
# 3      \t<info@clubcaddie.com>\n   <659888169528.7523837031@clubcaddie.com>\n
# 4              list@ListMe.com\n   <199803270247.VAA16763@rover.listme.com>\n
#
# index                                           Received  \
# index
# 0       from login_0246.whynot.net (mx.whynot.net[206...
# 1       from login_0122.ybecker.net (mail.ybecker.net...
# 2       from mail.anet-chi.com (1Cust245.tnt13.atl2.d...
# 3       from 207.212.50.128 [151.196.111.133] by mail...
# 4       (from list@localhost)\n\tby rover.listme.com ...
#
# index                                        Return-Path  Spam  \
# index
# 0                              <islander622@yahoo.com>\n  Spam
# 1                             <cm_offer@earthling.net>\n  Spam
# 2                                <carlover@goplay.com>\n  Spam
# 3       <owner-linux-kernel-outgoing@vger.rutgers.edu>\n  Spam
# 4                                    <list@listme.com>\n  Spam
#
# index                               Subject      ...        \
# index                                            ...
# 0               Re: Your Merchant Account\n      ...
# 1       I thought you might be interested\n      ...
# 2                  AUTOMOBILE OPPORTUNITY\n      ...
# 3                    What's in it for me?\n      ...
# 4            Your Search Engine Listing\n\n      ...
#
# index X-Centeq-MailScanner X-Centeq-MailScanner-From X-TM-AS-Product-Ver  \
# index
# 0                      NaN                       NaN                 NaN
# 1                      NaN                       NaN                 NaN
# 2                      NaN                       NaN                 NaN
# 3                      NaN                       NaN                 NaN
# 4                      NaN                       NaN                 NaN
#
# index X-TM-AS-Result Username SOURCE X-Env-Sender X-Msg-Ref  \
# index
# 0                NaN      NaN    NaN          NaN       NaN
# 1                NaN      NaN    NaN          NaN       NaN
# 2                NaN      NaN    NaN          NaN       NaN
# 3                NaN      NaN    NaN          NaN       NaN
# 4                NaN      NaN    NaN          NaN       NaN
#
# index X-StarScan-Version X-VirusChecked
# index
# 0                    NaN            NaN
# 1                    NaN            NaN
# 2                    NaN            NaN
# 3                    NaN            NaN
# 4                    NaN            NaN
#
# [5 rows x 722 columns]

# %% [markdown]
# Notice that some of the columns are duplicates, for eg. 'Message-Id', 'Message-ID' & 'Message-id', so we define a method to combine these duplicate columns.

# %%
def combineDuplicateColumns(df_final, colNames):
    originalCol = ''
    for i,duplicateCol in enumerate(colNames):
        if(i == 0):
            originalCol = duplicateCol
            continue
        
        df_final.loc[df_final[originalCol].isna(), originalCol] = df_final.loc[df_final[originalCol].isna()][duplicateCol]
    
    
    df_final.drop(labels=colNames[1:], axis=1, inplace=True)

# %%
# Combine duplicate columns
combineDuplicateColumns(df_final, ['Message-Id', 'Message-ID', 'Message-id'])
combineDuplicateColumns(df_final, ['Reply-To', 'Reply-to'])
combineDuplicateColumns(df_final, ['Mime-Version', 'MIME-version', 'MIME-Version'])
combineDuplicateColumns(df_final, ['Content-Type', 'Content-type'])
combineDuplicateColumns(df_final, ['Content-Transfer-Encoding', 'Content-transfer-encoding'])
combineDuplicateColumns(df_final, ['Error-To', 'Errors-To', 'Errors-to'])
combineDuplicateColumns(df_final, ['Content-Length','Content-length'])

# %% [markdown]
# Now that all duplicate columns are eliminated, lets display all columns of our final dataframe.

# %%
# Check for more duplicate columns
np.sort(df_final.columns.values)
# Out:
# array(['ADDRESS', 'AGE', 'ALERT', 'AT', 'Accreditor', 'Addressee', 'Age',
#        'Amount', 'Approved-By', 'Architecture', 'Arrival-Date', 'Article',
#        'Attention', 'Attn', 'Automatic-Legal-Notices', 'Availability',
#        'BIRTH', 'Bcc', 'Bericht', 'BioC2007', 'Bloomberg', 'Body',
#        'Bounce-To', 'Breakdown', 'BroadcastJobID', 'BroadcastRecipientID',
#        'CC', 'CITY', 'CODE', 'COMMENTS', 'COMPANY', 'Category', 'Cc',
#        'Cc\xa0', 'Cell', 'Cellular', 'Cialis', 'Cierre', 'Close',
#        'Coefficients', 'Comments', 'Complaints-To', 'Consider',
#        'Content-Base', 'Content-Class', 'Content-Description',
#        'Content-Disposition', 'Content-ID', 'Content-Length',
#        'Content-MD5', 'Content-Transfer-Encoding',
#        'Content-Transfer-encoding', 'Content-Type', 'Content-class',
#        'Content-description', 'Content-disposition', 'Content-language',
#        'Content-return', 'Coordinator', 'Correction', 'D.i.a.l', 'DBD',
#        'DBI->connect("dbi', 'DESIGN', 'DEVELOPMENT', 'DING-TOP',
#        'DKIM-Signature', 'Da', 'Data', 'Date', 'Delivered-To', 'Depends',
#        'Description', 'Dirección', 'Disclaimer', 'Distribution',
#        'DomainKey-Signature', 'DomainKey-Status', 'E-Mail', 'E-mail',
#        'EDITOR', 'EMAIL', 'EMU10K1X', 'EVENING', 'EXAMPLE', 'Eingabezeit',
#        'Email', 'Envelope-From', 'Error', 'Error-To', 'Example',
#        'Expiry-Date', 'F', 'FACT', 'FAX', 'FONT-FAMILY', 'FREE', 'FROM',
#        'FTA', 'Family', 'Fax', 'Fazit', 'Features', 'Fields', 'File',
#        'Final-Recipient', 'Firma', 'Flags', 'Folks', 'Format', 'Formula',
#        'From', 'Ganancias', 'Gastkommentar', 'George', 'Gestern', 'God',
#        'Group', 'HP', 'HREF=3D"http', 'Help', 'Here', 'Hi', 'Homepage',
#        'IBM', 'IMPORTANT', 'IO', 'IVA', 'In-Reply-To', 'In-reply-to',
#        'Injection-Info', 'Installed-Size', 'Instance', 'Internet',
#        'Investmentbanker', 'Inviato', 'K', 'Ku,rzel', 'Kurs', 'L00kup',
#        'LS&fs-100-SF', 'Lab', 'Last-Attempt-Date', 'Levels',
#        'Licence(http', 'Lines', 'List-Archive', 'List-ID', 'List-Id',
#        'List-Owner', 'List-Post', 'List-Subscribe', 'List-Unsubscribe',
#        'Localidad', 'Lost', 'MBOX-Line', 'MOTORSPORTS<BR>Sym',
#        'MOTORSPORTSSym', 'MSN', 'MTA', 'MUA', 'Mail-Copies-To',
#        'Mailing-List', 'Maintainer', 'Markt', 'Medienb=FCndel',
#        'Medienforum', 'Message', 'Message-Id', 'Message-Type',
#        'Mime-Version', 'Mime-version', 'Mobile', 'Msn', 'NIGHT)',
#        'NNTP-Posting-Date', 'NNTP-Posting-Host', 'NO', 'NT-SIZE',
#        'NUMBER', 'Nachricht', 'Nachrichtenart', 'Names', 'Nationality',
#        'Newsgroups', 'Ningbo', 'Note', 'O<http', 'OCCUPATION', 'OS',
#        'OTCBB', 'Office', 'Oggetto', 'Operating-system',
#        'Original-recipient', 'PRICE', 'PS&fs-100-SF', 'Parcels', 'Paris',
#        'Password', 'Path', 'Ph', 'Platform', 'Portal', 'Preis', 'Private',
#        'Product', 'Project', 'Proposition', 'Provincia', 'Q', 'Questions',
#        'RESIDENCE', 'RT-Attachment', 'RT-Originator',
#        'RU;mso-bidi-language', 'Rating', 'Re', 'Received',
#        'Received-From-MTA', 'Reception', 'Recommendation', 'Refernces',
#        'Remote-MTA', 'Reply-To', 'Resent-Cc', 'Resent-Date',
#        'Resent-From', 'Resent-Message-ID', 'Resent-Message-Id',
#        'Resent-Sender', 'Resent-To', 'Return-Path',
#        'Return-route-verification', 'Reuters', 'Russia', 'S.ymboL', 'SEX',
#        'SIGNIFICAR=C1', 'SMB', 'SOURCE', 'STATE', 'SYMBOL', 'Section',
#        'See', 'Sender', 'Sensitivity', 'Solution', 'Spam', 'Spieh',
#        'Standard', 'Status', 'Structure', 'Su.mbol', 'Subject',
#        'Substance', 'Sumb0l', 'Summary', 'Suppose', 'Sym', 'Symb.oL', 'T',
#        'T&#214;CKER', 'TARGET', 'TO', 'TODAY)', 'TONIGHT)', 'Target',
#        'Tel.', 'Tel./Fax', 'Telephone', 'Teléfono', 'Testimonials',
#        'Thread-Index', 'Thread-Topic', 'Thread-index', 'Thread-topic',
#        'Tname', 'To', 'Toaster', 'Trade', 'USPS', 'Uh', 'Unlock',
#        'Unsubscribe', 'UsedCars', 'User-Agent', 'Username', 'VOICE',
#        'Venezuela', 'Verbreitungsnetzwerk', 'Verbreitungssysteme',
#        'Version', 'Verzicht', 'Veröffentlichungszeit', 'Viagra', 'Voice',
#        'WWW', 'Wanted', 'Warning', 'Web', 'WebSVN',
#        'Wertpapier-Kenn-Nummer', 'Will-Retry-Until', 'WorldWide<br>-',
#        'X-AOL-IP', 'X-ASG-Debug-ID', 'X-ASG-Orig-Subj', 'X-ASG-Whitelist',
#        'X-Abuse', 'X-Abuse-and-DMCA-Info', 'X-Accept-Language',
#        'X-Account-Key', 'X-Ack', 'X-Actual-Recipient', 'X-Amavis-Alert',
#        'X-Anti-Virus', 'X-AntiAbuse', 'X-AntiVirus', 'X-Antispam-ID',
#        'X-Antivirus', 'X-Antivirus-ACN', 'X-Antivirus-ACN-Mail-From',
#        'X-Antivirus-ACN-Message-ID', 'X-Antivirus-CMCFLEX',
#        'X-Antivirus-CMCFLEX-Mail-From', 'X-Antivirus-DRIM',
#        'X-Antivirus-DRIM-Mail-From', 'X-Antivirus-Status',
#        'X-Apparently-To', 'X-AuditID', 'X-Auth-Received',
#        'X-Authenticated', 'X-Authenticated-Sender',
#        'X-Authenticated-User', 'X-Authentication-Warning', 'X-BPS1',
#        'X-Barracuda-Bayes', 'X-Barracuda-Connect',
#        'X-Barracuda-Encrypted', 'X-Barracuda-Spam-Report',
#        'X-Barracuda-Spam-Score', 'X-Barracuda-Spam-Status',
#        'X-Barracuda-Start-Time', 'X-Barracuda-URL',
#        'X-Barracuda-Virus-Scanned', 'X-BeenThere', 'X-BigFish',
#        'X-BitDefender-Scanner', 'X-Brightmail-Tracker',
#        'X-Brightmail-scanned', 'X-BrightmailFiltered',
#        'X-Bugzilla-Component', 'X-Bugzilla-Product', 'X-Bugzilla-Reason',
#        'X-Bulkmail', 'X-CGUID', 'X-CSIR-MailScanner', 'X-Cam-AntiVirus',
#        'X-Cam-ScannerInfo', 'X-Cam-SpamDetails', 'X-Centeq-MailScanner',
#        'X-Centeq-MailScanner-From', 'X-Chzlrs', 'X-ClamAV', 'X-Comment',
#        'X-Comments', 'X-Complaints-To', 'X-Content-Filtered-By',
#        'X-CountryCode', 'X-Ctuhulu', 'X-DKIM', 'X-DMCA-Complaints-To',
#        'X-DMCA-Notifications', 'X-DSNContext', 'X-DSPAM-Confidence',
#        'X-DSPAM-Factors', 'X-DSPAM-Probability', 'X-DSPAM-Result',
#        'X-DSPAM-Signature', 'X-Debian-PR-Keywords', 'X-Debian-PR-Message',
#        'X-Debian-PR-Package', 'X-Debian-PR-Source', 'X-Debian-Version',
#        'X-Destination-ID', 'X-DomainKeys', 'X-ECS-MailScanner-BBSRC',
#        'X-ELNK-Trace', 'X-EN-CGIPath', 'X-EN-CGIUser', 'X-EN-Info',
#        'X-EN-OrigIP', 'X-Edinburgh-Scanned', 'X-Enigmail-Supports',
#        'X-Enigmail-Version', 'X-Env-Sender', 'X-Envelope-From',
#        'X-Envelope-To', 'X-ExtScanner', 'X-FHCRC-SCANNED', 'X-Face',
#        'X-Firewall-Bypass', 'X-Fraunhofer-Email-Policy', 'X-From_',
#        'X-GMX-Antivirus', 'X-Gentoo-Version', 'X-Gmane-NNTP-Posting-Host',
#        'X-Google-Sender-Auth', 'X-Greylist', 'X-HTTP-Host',
#        'X-HTTP-UserAgent', 'X-HTTP-Useragent', 'X-HTTP-Via',
#        'X-Habeas-Report', 'X-Header', 'X-ID', 'X-IMAIL-SPAM-PREMIUM',
#        'X-IP', 'X-ISS-MailScanner', 'X-ISS-MailScanner-Information',
#        'X-ISS-MailScanner-SpamCheck', 'X-ImpeachBushNow',
#        'X-ImpeachBushNow-Information', 'X-Injected-Via-Gmane',
#        'X-IronPort-AV', 'X-IronPort-Anti-Spam-Filtered',
#        'X-IronPort-Anti-Spam-Result', 'X-Junkmail-SD-Raw',
#        'X-Junkmail-Status', 'X-Kaspersky-Antivirus', 'X-Keywords',
#        'X-Kontent-Script', 'X-Kontent-Sender', 'X-LSV-ListID',
#        'X-LYRIS-Message-Id', 'X-Lava-net-MailScanner',
#        'X-Lava-net-MailScanner-From', 'X-Library', 'X-List-Administrivia',
#        'X-List-Owner-Address', 'X-List-Software', 'X-Location',
#        'X-Loom-IP', 'X-Loop', 'X-Lumos-SenderID', 'X-M',
#        'X-MB-Message-Source', 'X-MB-Message-Type', 'X-MDRcpt-To',
#        'X-MDaemon-Deliver-To', 'X-ME-UUID', 'X-MHO-User',
#        'X-MIME-Autoconverted', 'X-MIMEOLE', 'X-MIMETrack',
#        'X-MS-Has-Attach', 'X-MS-TNEF-Correlator', 'X-MSMail-Priority',
#        'X-MSMail-priority', 'X-MSReally-From', 'X-MSmail-Priority',
#        'X-Mail-Filters-SPAM', 'X-Mail-Handler', 'X-MailScanner-From',
#        'X-Mailer', 'X-Mailing-List', 'X-Mailing-List-Name', 'X-MailingID',
#        'X-Mailman-Approved-At', 'X-Mailman-Version', 'X-Major',
#        'X-Message-Id', 'X-Message-Info', 'X-Miltered',
#        'X-Mime-Autoconverted', 'X-MimeOLE', 'X-Mimeole',
#        'X-Modus-BlackList', 'X-Modus-Trusted', 'X-Mozilla-Status',
#        'X-Mozilla-Status2', 'X-Msg-Ref', 'X-NAI-Checker-Version',
#        'X-NAI-Spam-Flag', 'X-NAI-Spam-Report', 'X-NAI-Spam-Rules',
#        'X-NAI-Spam-Score', 'X-NAI-Spam-Threshold', 'X-NAIMIME-Disclaimer',
#        'X-NAIMIME-Modified', 'X-Nabble-From', 'X-Newsgroups',
#        'X-Newsreader', 'X-No-Archive', 'X-No-CC', 'X-Nominal',
#        'X-Old-Spam-Check-By', 'X-Old-Spam-Status', 'X-Operating-System',
#        'X-Operating-system', 'X-Orcpt', 'X-Organisation',
#        'X-Original-Date', 'X-Original-Newsgroups',
#        'X-Original-References', 'X-Original-To', 'X-OriginalArrivalTime',
#        'X-Originating-Email', 'X-Originating-Heisenberg-IP',
#        'X-Originating-IP', 'X-Originating-Pythagoras-IP',
#        'X-Originating-Rutherford-IP', 'X-Originating-Server',
#        'X-OriginatingIP', 'X-Oxford-Username', 'X-PGP', 'X-PGP-Key',
#        'X-PHP-Script', 'X-PM', 'X-PM-RogueFiles', 'X-PM-Scan',
#        'X-PMFLAGS', 'X-PMX-Spam', 'X-PMX-Spam-Level', 'X-PMX-Version',
#        'X-PPLU', 'X-PPS', 'X-PTS-Keyword', 'X-PTS-Package',
#        'X-PerlMx-Spam', 'X-Poco-Status', 'X-Poco-UID',
#        'X-PopBeforeSMTPSenders', 'X-Possible-Spoof', 'X-Post-From',
#        'X-Posted-By', 'X-Postfilter', 'X-Priority',
#        'X-Proofpoint-Spam-Reason', 'X-Proofpoint-Virus-Version',
#        'X-Provags-ID', 'X-Public-Key-Fingerprint', 'X-Public-Key-ID',
#        'X-Public-Key-URL', 'X-QUOTATION', 'X-Qmail-Scanner-Message-ID',
#        'X-RAV-AntiVirus', 'X-RAV-Antivirus', 'X-RFC2646',
#        'X-RT-Loop-Prevention', 'X-RT-NewTicket', 'X-RT-Original-Encoding',
#        'X-RZG-AUTH', 'X-RZG-CLASS-ID', 'X-Rc-Spam', 'X-Rc-Virus',
#        'X-Received', 'X-Recipient', 'X-RedirectStatus',
#        'X-Remote-Browser', 'X-Report-Abuse-To', 'X-Return-Path',
#        'X-Return-Path-Hint', 'X-Roving-CampaignId', 'X-Roving-ID',
#        'X-Roving-StreamId', 'X-SA-Exim-Connect-IP', 'X-SA-Exim-Mail-From',
#        'X-SA-Exim-Scanned', 'X-SA-Exim-Version', 'X-SBRS-GW1',
#        'X-SEF-Processed', 'X-SGUL-MailScanner-From',
#        'X-SGUL-MailScanner-MH1', 'X-SGUL-MailScanner-SpamCheck',
#        'X-SMFBL', 'X-SMHeaderMap', 'X-SMTP-Vilter-Version', 'X-SPLN-ID',
#        'X-ST-MF-Message-Resent', 'X-Sasl-enc', 'X-Scan-Signature',
#        'X-Scanned', 'X-Scanned-By', 'X-Scanner', 'X-Sender', 'X-SenderIP',
#        'X-Sensitivity', 'X-Server-Uuid', 'X-Sieve', 'X-Source',
#        'X-Source-Args', 'X-Source-Dir', 'X-SourceForge-Tracker-itemid',
#        'X-Spam', 'X-Spam-Abuse', 'X-Spam-Autolearn', 'X-Spam-Check-By',
#        'X-Spam-Checker-Version', 'X-Spam-DCCD-Results', 'X-Spam-Flag',
#        'X-Spam-Level', 'X-Spam-Processed', 'X-Spam-RBL-Results',
#        'X-Spam-Report', 'X-Spam-Scan-Date', 'X-Spam-Score',
#        'X-Spam-Scored', 'X-Spam-See', 'X-Spam-Status', 'X-Spam-Summary',
#        'X-Spam-Tests', 'X-SpamTest-Envelope-From', 'X-SpamTest-Group-ID',
#        'X-SpamTest-Info', 'X-SpamTest-Method', 'X-SpamTest-Rate',
#        'X-SpamTest-Status', 'X-SpamTest-Status-Extended',
#        'X-SpamTest-Version', 'X-Spam_bar', 'X-Spam_report',
#        'X-Spam_score', 'X-Spam_score_int', 'X-Spamfilter-host',
#        'X-StarScan-Version', 'X-Subscription', 'X-TM-AS-Product-Ver',
#        'X-TM-AS-Result', 'X-TMWD-Spam-Summary', 'X-TPG-Antivirus',
#        'X-Terra-Hash', 'X-Terra-Karma', 'X-To', 'X-Trace', 'X-Trusted',
#        'X-UCInetID', 'X-UCL-MailScanner', 'X-UCL-MailScanner-From',
#        'X-UCL-MailScanner-Information', 'X-UCSC-CATS-MailScanner-From',
#        'X-UCSC-EDU-MIMEDefang', 'X-UCSC-EDU-Sender', 'X-UGUID', 'X-UIDL',
#        'X-UNB-MailScanner-Information', 'X-UNB-SpamDetails',
#        'X-UNB-VirusScanner', 'X-UQ-FilterTime', 'X-URI-Orig', 'X-URL',
#        'X-USER_IP', 'X-UUID', 'X-UVA-Virus-Scanned',
#        'X-UWMath-MailScanner', 'X-Uidl', 'X-Unsubscribe',
#        'X-Useless-Header', 'X-Userid', 'X-Uwash-Spam', 'X-Verification',
#        'X-VirtualServer', 'X-VirtualServerGroup', 'X-Virus-Checked',
#        'X-Virus-Scanned', 'X-Virus-Status', 'X-VirusChecked', 'X-WSS-ID',
#        'X-Whitelist', 'X-X-QUOTATION', 'X-X-Sender', 'X-XaM3-API-Version',
#        'X-Y-GMX-Trusted', 'X-YMail-OSG', 'X-Yahoo-Newman-Id',
#        'X-Yahoo-Newman-Property', 'X-YaleITSMailFilter', 'X-Zipped',
#        'X-bandanestring.com-MsgID', 'X-cPanel-MailScanner',
#        'X-cPanel-MailScanner-From', 'X-centerballoning.com-MsgID',
#        'X-doormobiles.com-MsgID', 'X-ecartis-antiloop', 'X-imss-result',
#        'X-imss-settings', 'X-imss-tmaseResult',
#        'X-lookedleftlast.com-MsgID', 'X-mailed-to', 'X-mailer',
#        'X-nicktalktime.com-MsgID', 'X-notifreq', 'X-pstn-addresses',
#        'X-pstn-levels', 'X-pstn-neptune', 'X-pstn-settings', 'X-remove',
#        'X-screenslates.com-MsgID', 'X-twelveapples.com-MsgID',
#        'X-www2.ttands.com-MsgID', 'XAuthentication-Warning',
#        'XMessage-Id', 'X_Id', 'X_email_KEY', 'Xanaax', 'À\xa0',
#        'ÁªÏµµç»°', 'ÁªÏµÈË', 'ÌÑÊ-', 'Ò»', 'Ö÷½²¿Î³Ì'], dtype=object)

# %% [markdown]
# Let's keep the columns that we need and eliminate the rest.

# %%
#From, To, Body, Subject, Message-Id, X-UIDL, Sender, Spam
c1 = df_final.columns
c2 = pd.Index(['Spam', 'Body', 'Subject', 'From', 'To', 'Message-Id', 'X-UIDL', 'Sender'])
c1 = c1.difference(c2)

df_new = df_final.drop(labels=c1.format(), axis=1, inplace=False)
df_new.columns
# Out:
# Index(['Body', 'From', 'Message-Id', 'Spam', 'Subject', 'To', 'X-UIDL',
#        'Sender'],
#       dtype='object', name='index')

# %% [markdown]
# Here is our final dataframe. We now have data in a structured format. Saving it as "structured.xlsx".

# %%
df_new.head()

# %%
excelwriter = pd.ExcelWriter('structured.xlsx', engine='xlsxwriter')

df_new.to_excel(excelwriter, index=False)

excelwriter.save()
# Out:
# /usr/local/lib/python3.6/dist-packages/xlsxwriter/worksheet.py:832: UserWarning: Ignoring URL 'http://www.prize4life.org/aboutprize4life.html
#
# about%20prize4life
#
# his%20latest%20idea%20is%20to%20offer%20$10%20million%20%5bin%5d%20prize%5bs%5d,%20prize4life,
# to%20create%20buzz%20and%20attract%20researchers%20to%20solve%20the%20puzzles%20of%20als,
# much%20as%20the%20x%20prize%20stimulated%20private%20teams%20to%20build%20a
# spacecraft%20.%20.%20.%20it%20is%20all%20about%20harnessing%20market%20forces%20to%20his
# goal,%20mr.%20kremer%20says.
#
# %20the%20wall%20street%20journal
#
# what%20is%20prize4life?
#
# prize4life%20is%20a%20results-oriented%20nonprofit%20founded%20to%20accelerate%20als/
# mnd%20research%20by%20offering%20substantial%20prizes%20to%20scientists%20who%20solve
# the%20most%20critical%20scientific%20problems%20preventing%20the%20discovery%20of%20an
# effective%20als/mnd%20treatment.
#
# the%20prize4life%20concept%20is%20inspired%20by%20other%20prize%20awards%20for
# stimulating%20research,%20such%20as%20the%20x-prize%20for%20commercial%20space%20travel
# and%20dna-decoding,%20the%20u.s.%20governments%20h-prize%20for%20hydrogen
# renewable%20energy,%20and%20eli%20lillys%20venture,%20innocentive,%20which
# outsources%20difficult%20r&d%20problems%20to%20a%20distributed%20network%20of
# scientists%20using%20prizes.
#
# why%20launch%20prizes%20for%20als/mnd%20research?
#
# *%20%20prizes%20will%20act%20as%20a%20lighthouse%20for%20all%20of%20als/mnd%20research%20
# directing%20scientists%20to%20focus%20on%20solving%20the%20als%20problems%20most
# critical%20to%20discovering%20an%20effective%20treatment.
# *%20%20prizes%20will%20provide%20the%20right%20incentives%20for%20the%20right%20academic
# ideas%20to%20be%20taken%20outside%20of%20the%20laboratory%20and%20commercialized%20for
# als/mnd%20patients.
# *%20%20prizes%20will%20remove%20the%20largest%20impediments%20to%20industrys
# involvement%20in%20als/mnd.
#
# what%20makes%20prize4life%20distinctive?
#
# *%20%20prize4life%20only%20pays%20for%20results%20-%20the%20results%20that%20als/mnd
# patients%20desperately%20need.
#
# *%20%20prize4life%20is%20uniquely%20positioned%20to%20offer%20als/mnd%20prizes%20because
# we%20bring%20together%20existing%20als%20nonprofits,%20academia,%20and%20industry%20
# all%20working%20toward%20an%20als/mnd%20treatment.
#
# what%20will%20we%20offer%20prizes%20for?
#
# 1)%20biomarker/diagnostic%20tool:%20%20a%20test%20or%20exam%20that%20will%20allow%20us%20to
# staffers%20for%20four%20key%20senators%20have%20met%20for%20weeks,%20finessing%20the%20details
# of%20legislation%20to%20give%20the%20food%20and%20drug%20administration%20new%20powers%20to
# approve%20generic%20versions%20of%20biologics%20--%20therapies%20based%20on%20living
# organisms%20.
#
# already,%20generics%20that%20are%20the%20chemical%20equivalents%20of%20name-brand%20drugs
# save%20patients%20and%20the%20federal%20government%20billions%20annually.
#
# the%20compromise%20bill%20unveiled%20yesterday%20represents%20a%20delicate%20balancing
# act,%20said%20senator%20edward%20m.%20kennedy%20,%20democrat%20of%20massachusetts%20.
#
# it%20would%20speed%20generic%20biologic%20drugs%20to%20market%20by%20requiring%20fewer
# clinical%20trials%20before%20approval,%20while%20maintaining%20financial%20incentives
# for%20such%20biotechnology%20leaders%20as%20cambridge's%20genzyme%20corp.%20and%20biogen
# idec%20inc.,%20which%20funnel%20revenue%20into%20development%20pipelines%20to%20produce
# more%20biologic%20treatments.
#
# %22congress%20has%20a%20responsibility%20to%20encourage%20the%20innovation%20that%20leads%20to
# these%20new%20medical%20miracles,%20and%20to%20see%20that%20they%20are%20affordable%20for%20the
# patients%20who%20need%20them,%22%20kennedy%20said%20in%20a%20statement.%20%22our%20bipartisan
# legislation%20also%20includes%20strong%20and%20responsible%20incentives%20to%20encourage
# dynamic%20new%20biotechnology%20companies%20to%20invest%20in%20the%20innovations%20that
# will%20produce%20the%20cures%20of%20tomorrow.%22
#
# among%20the%20most%20contentious%20issues%20was%20how%20long%20of%20a%20safe%20haven%20to%20give
# branded%20biologics%20before%20generics%20could%20compete%20for%20the%20same%20business.
#
# biotech%20companies%20wanted%2014%20years%20of%20market%20exclusivity.%20a%20letter%20signed
# by%20aarp%20and%20others%20said%20that%20%22would%20unnecessarily%22%20limit%20access%20to
# affordable%20drugs%20and%20%22would%20actually%20have%20the%20perverse%20effect%20of
# reducing%20incentives%20to%20innovate.%22%20generic%20manufacturers%20and%20their
# supporters%20said%20five%20years%20was%20sufficient.
#
# in%20the%20end,%20the%20senate%20opted%20for%2012%20years,%20as%20was%20strongly%20advocated%20by
# senator%20orrin%20hatch%20,%20republican%20of%20utah%20.%20the%20bipartisan%20bill's%20other
# sponsors%20are%20senators%20hillary%20rodham%20clinton%20,%20democrat%20of%20new%20york%20,
# and%20michael%20enzi%20,%20republican%20of%20wyoming%20.
#
# but%20generic%20manufacturers%20are%20still%20poised%20to%20save%20money%20on%20their
# development%20costs%20through%20a%20speedier%20path%20to%20market%20that%20leverages%20what
# the%20fda%20already%20knows%20about%20the%20safety%20and%20effectiveness%20of%20the%20branded
# versions%20of%20biologics.
#
# in%20some%20cases,%20the%20fda%20could%20waive%20clinical%20trials%20in%20humans%20prior%20to
# approval,%20according%20to%20kennedy's%20office.
#
# already,%20novartis%20ag%20is%20poised%20to%20seize%20on%20the%20opportunity.%20the%20drug
# maker%20said%20yesterday%20that%20its%20generic%20version%20of%20a%20blood-building
# therapy%20drug%20epoetin%20alfa%20is%20close%20to%20reaching%20the%20market%20in%20europe%20.
# the%20anemia%20remedy%20is%20sold%20under%20the%20brand%20names%20epogen%20and%20procrit%20and
# accounts%20for%20such%20a%20staggering%20portion%20of%20federal%20pharmaceutical
# spending%20that%20congressional%20watchdogs%20have%20eyed%20their%20marketing%20and
# sales%20growth.
#
# but%20generic%20manufacturers%20like%20novartis%20would%20be%20subject%20to%20the%20same
# risk%20management%20plans%20contained%20in%20fda%20reform%20legislation%20that%20passed
# the%20senate%20and%20is%20pending%20in%20the%20house.
#
# that%20legislation%20opens%20the%20door%20for%20generic%20manufacturers%20to%20conduct
# post%20marketing%20clinical%20trials%20after%20their%20products%20are%20made%20available
# for%20sale.
#
# another%20sticking%20point%20in%20the%20senators'%20deliberation%20was%20how%20pharmacists
# should%20handle%20prescriptions%20for%20the%20newest%20generics.
#
# now,%20for%20instance,%20pharmacists%20can%20fill%20a%20prescription%20for%20the
# cholesterol%20drug%20zoo%20with%20the%20generic%20version%20without%20first%20consulting
# the%20physician.%20pharmacists%20could%20one%20day%20do%20the%20same%20for%20generic
# biologics,%20under%20the%20compromise%20bill.
#
# the%20generic%20manufacturer%20would%20have%20to%20prove%20its%20drug%20is%20similar%20to%20the
# name%20version%20and%20the%20fda%20would%20have%20to%20vouch%20that%20it%20had%20sufficient
# evidence%20that%20the%20two%20products%20produce%20the%20same%20clinical%20result.
#
# the%20senate%20measure%20is%20scheduled%20to%20clear%20a%20key%20committee%20on%20wednesday%20.
#
# diedtra%20henderson%20can%20be%20reached%20at%20dhenderson@globe.com.
#
# --
# mike%20palmedo
# research%20coordinator
# program%20on%20information%20justice%20and%20intellectual%20property
# american%20university,%20washington%20college%20of%20law
# 4910%20massachutsetts%20ave.,%20nw%20washington,%20dc%2020016
# t%20-%20202-274-4442%20|%20f%20202-274-0659
# mpalmedo@wcl.american.edu
#
#
# _______________________________________________
# ip-health%20mailing%20list
# ip-health@lists.essential.org
# http://lists.essential.org/mailman/listinfo/ip-health' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/dist-packages/xlsxwriter/worksheet.py:832: UserWarning: Ignoring URL 'http://agreeput.hk
#
#
#
#
#
# viagra
#
# 60%20pills%20x%2050mg$111.65$1.86%20per%20itemyour%20save:%20$7030%20pills%20x%2050mg$60.23$2.01%20per%20itemyour%20save:%20$3010%20pills%20x%20100mg$34.49$3.45%20per%20item%2030%20pills%20x%20100mg$88.5$2.95%20per%20itemyour%20save:%20$1560%20pills%20x%20100mg$141$2.35%20per%20itemyour%20save:%20$6690%20pills%20x%20100mg$176.4$1.96%20per%20itemyour%20save:%20$13410%20pills%20x%2050mg$30.22$3.03%20per%20item%20viagra%20%20soft%20tabs%2060%20pills%20x%2050mg%20%20$123.2%20%20$2.05%20per%20item%20%20your%20save:%20$77%20%2030%20pills%20x%20100mg%20%20$97.35%20%20$3.25%20per%20item%20%20your%20save:%20$16%20%2060%20pills%20x%20100mg%20%20$155.1%20%20$2.59%20per%20item%20%20your%20save:%20$72%20%2010%20pills%20x%20100mg%20%20$37.94%20%20$3.8%20per%20item%20%20%20%20%2030%20pills%20x%2050mg%20%20$66.28%20%20$2.21%20per%20item%20%20your%20save:%20$34%20%2090%20pills%20x%20100mg%20%20$194.04%20%20$2.16%20per%20item%20%20your%20save:%20$147%20%2010%20pills%20x%2050mg%20%20$33.25%20%20$3.33%20per%20item%20%20%20%20
# %20$3.83%20per%20item%20%20your%20save:%20$2%20
# %2010%20pills%20x%2020mg%20%20$39.19%20%20$3.92%20per%20item%20%20%2060%20pills%20x%2020mg%20%20$180.15%20%20$3%20per%20i=
# tem%20%20your%20save:%20$55%20
# %2090%20pills%20x%2020mg%20%20$242.06%20%20$2.69%20per%20item%20%20your%20save:%20$111%20
#
# viagra%20jelly
# %2060%20pills%20x%20100mg%20%20$187.97%20%20$3.14%20per%20item%20%3c=
# td%3e%20your%20save:%20$1%20
# %2030%20pills%20x%20100mg%20%20$92.4%20%20$3.08%20per%20item%20%20your%20save:%20$1%20
# %2010%20pills%20x%20100mg%20%20$30.02%20%20$3%20per%20item%20%20=
# your%20save:%20$1%20%2090%20pills%20x%20100mg%20%20$207.9%20%20$2.31%20per%20item%20%20your%20save:%20$74%20
# levitra
# %2090%20pills%20x%2020mg%20%20$246.57%20%20$2.74%20per%20item%20%20your%20save:%20$1%20%2030%20pills%20x%2020mg%20%20$82.01%20%3c=
# td%3e%20$2.73%20per%20item%20%20your%20save:%20$1%20
# %2020%20pills%20x%2020mg%20%20$54.99%20%20$2.75%20per%20item%20%20
# %2010%20pills%20x%2020mg%20%20$27.08%20%20$2.71%20per%20item%20%20
# %2060%20pills%20x%2020mg%20%20$164.36%20%20$2.74%20per%20item%20%20your%20save:%20$1%20
#
# http://languagepick.hk
#
#
# ------=_nextpart_000_0007_01c7be6c.a35c7780--' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/dist-packages/xlsxwriter/worksheet.py:832: UserWarning: Ignoring URL 'https://bugzilla.samba.org/show_bug.cgi?id=4600
#
# %20%20%20%20%20%20%20%20%20%20%20summary:%20make%20python_ext%20fails%20for%203.0.25rc3
# %20%20%20%20%20%20%20%20%20%20%20product:%20samba%203.0
# %20%20%20%20%20%20%20%20%20%20%20version:%203.0.25
# %20%20%20%20%20%20%20%20%20%20platform:%20all
# %20%20%20%20%20%20%20%20os/version:%20all
# %20%20%20%20%20%20%20%20%20%20%20%20status:%20new
# %20%20%20%20%20%20%20%20%20%20severity:%20normal
# %20%20%20%20%20%20%20%20%20%20priority:%20p3
# %20%20%20%20%20%20%20%20%20component:%20python
# %20%20%20%20%20%20%20%20assignedto:%20tpot@samba.org
# %20%20%20%20%20%20%20%20reportedby:%20m.proehl@science-computing.de
# %20%20%20%20%20%20%20%20%20qacontact:%20samba-qa@samba.org
#
#
# building%20python%20extension%20via%20make%20python_ext%20fails:
#
# %20%20...
# %20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20from%20python/py_spoolss_printers_conv.c:21:
# /usr/include/features.h:150:1:%20warning:%20this%20is%20the%20location%20of%20the%20previous
# definition
# python/py_spoolss_printers_conv.c:106:%20error:%20structure%20has%20no%20member%20named
# %60flags'
# python/py_spoolss_printers_conv.c:106:%20error:%20initializer%20element%20is%20not
# constant
# python/py_spoolss_printers_conv.c:106:%20error:%20(near%20initialization%20for
# %60py_printer_info_3%5b0%5d.offset')
# python/py_spoolss_printers_conv.c:106:%20error:%20initializer%20element%20is%20not
# constant
# python/py_spoolss_printers_conv.c:106:%20error:%20(near%20initialization%20for
# %60py_printer_info_3%5b0%5d')
# %2030%20pills%20x%20100mg%20%20$97.35%20%20$3.25%20per%20item%20%20your%20save:%20$16%20
# ...
# development%20and%20maintenance%20costs%20associated%20with%20building%20the%20product.
#
#
# bhaskar%20has%20a%20rare%20cancer%20-%20chronic%20myeloid%20leukaemia%20(cml).%20about
# 30,000%20indians%20are%20diagnosed%20with%20the%20disease%20every%20year.%20the%20drugs%20that
# cpaa%20gives%20him%20cost%20rs%2010,000%20a%20month.%20and%20that's%20cheap.%20he%20takes%20the
# generic%20versions,%20the%20copies,%20made%20by%20indian%20companies.%20the%20original,
# usually%20called%20glivec,%20owned%20by%20swiss%20pharma%20giant,%20novartis,%20would%20have
# cost%20him%20over%20rs%201,20,000%20a%20month.
#
# novartis%20is%20at%20the%20moment%20in%20a%20battle%20with%20the%20cpaa%20and,%20in%20a%20way,%20the
# indian%20government,%20to%20win%20the%20exclusive%20marketing%20rights%20for%20glivec
# which%20will%20result%20in%20local%20companies%20being%20ordered%20to%20stop%20making
# cheaper%20copies%20of%20the%20drug.
#
# novartis%20says%20that%20it%20invented%20the%20base%20compound%20(imatinib)%20and%20deserves
# the%20exclusive%20rights%20to%20market%20it.%20the%20appeal%20of%20novartis,%20till%20recently
# heard%20by%20the%20madras%20high%20court,%20has%20now%20been%20transferred%20to%20the%20newly
# created%20intellectual%20property%20appellate%20board%20(ipab)%20which%20is%20expected
# to%20pass%20a%20verdict%20soon.
#
# at%20stake%20is%20a%20very%20complex%20issue,%20almost%20philosophical.%20that%20the%20poor
# have%20a%20right%20to%20live%20is%20a%20truth%20that%20has%20no%20meaning%20if%20there%20are%20no
# life-saving%20drugs%20in%20the%20first%20place.%20and%20it%20is%20not%20the%20goodness%20of
# activists%20that%20cures%20diseases,%20but%20the%20commercial%20motives%20of%20big%20pharma
# companies%20like%20novartis%20which%20spawn%20multi-million%20dollar%20research.
#
# if%20novartis%20wins%20the%20battle%20for%20glivec,%20indian%20generics,%20whom%20the%20swiss
# company's%20ceo%20daniel%20vasella%20had%20once%20described%20as%20%22thieves%22,%20will%20be
# wiped%20out%20and%20not%20only%20a%20cancer%20cure%20but%20also%20hiv,%20tb%20and%20other
# treatments%20will%20become%20many%20times%20more%20expensive.%20the%20ramifications%20of
# the%20glivec%20battle%20is%20so%20important%20to%20the%20commerce%20of%20cure%20and%20the%20very
# meaning%20of%20a%20poor%20person's%20life%20in%20a%20capitalistic%20world,%20that
# journalists%20from%20the%20first%20world,%20especially%20europe,%20have%20been%20landing
# in%20the%20country%20in%20the%20last%20few%20weeks.
#
# at%20the%20heart%20of%20the%20battle,%20as%20always,%20is%20a%20technicality.%20it%20is%20called,
# without%20affection%20by%20novartis,%203d.%20it%20is%20a%20section%20in%20the%20indian%20patents
# act.%20the%20base%20compound%20of%20glivec%20was%20invented%20in%201993.%20it%20was%20only%20two
# years%20later%20that%20india%20joined%20the%20world%20trade%20organisation.
#
# india%20said%20that%20over%20the%20next%2010%20years,%20as%20it%20moved%20towards%20a%20patents
# regime,%20it%20would%20consider%20fresh%20patent%20applications%20of%20inventions%20that
# did%20not%20exist%20before%201995.%20so%20the%20original%20base%20compound%20of%20glivec%20did
# not%20qualify,%20but%20novartis%20filed%20for%20patent%20for%20a%20slight%20variation,%20a
# beta%20crystal%20form.
#
# in%202003,%20novartis%20was%20granted%20the%20exclusive%20marketing%20rights%20for%20that.
# but%20when%20the%20indian%20patent%20law%20came%20into%20effect%20in%202005,%20there%20was%20a
# clause%20in%20section%203d%20that%20implied%20that%20cosmetic%20variations,%20like%20the
# beta%20crystal%20form%20of%20imatinib,%20cannot%20be%20considered.%20so,%20in%202006,
# novartis%20lost%20its%20exclusive%20rights%20and%20the%20indian%20generics%20who%20were
# debarred%20from%20making%20copies%20rose%20again.
#
# novartis%20claims%20that%20it%20is%20only%20fighting%20for%20its%20rights%20and%20not%20for
# money.%20a%20spokesperson%20of%20the%20company%20says%20that%20its%20glivec%20international
# patient%20assistance%20program%20(gipap)%20has%20given%20the%20drug%20free%20to%208,000
# patients%20in%20india.%20%22ninety-nine%20percent%20of%20the%20indians%20who%20have%20been
# taking%20glivec,%20have%20been%20getting%20it%20free.%22
#
# it%20is%20a%20claim%20that%20makes%20y%20k%20sapru,%20the%20gritty%20chief%20of%20cpaa,%20a%20former
# pharma%20executive%20himself,%20laugh.%20%22what%20they%20don't%20tell%20you%20is%20that%20they
# give%20the%20drug%20to%20patients%20free%20for%20one%20or%20two%20months,%20that's%20all.
# novartis%20is%20not%20here%20for%20social%20service.%20it%20is%20here%20to%20make%20money.%20last
# year,%20glivec%20made%20$2.6%20billion%20worldwide.%20they%20want%20to%20make%20more%20money.
# and%20this%20argument%20that%20they%20deserve%20to%20earn%20because%20they%20invested%20in%20the
# research%20of%20the%20drug%20is%20not%20very%20good.%20fifty%20percent%20of%20the%20funding%20came
# from%20the%20us%20government,%2030%25%20from%20a%20us%20ngo%20and%2010%25%20from%20the%20oregon%20health
# and%20science%20institute.%20only%2010%25%20came%20from%20novartis.%22(novartis%20did%20not
# respond%20when%20asked%20for%20a%20confirmation.)
#
# a%20few%20months%20ago,%20novartis%20ceo%20daniel%20vasella%20is%20reported%20to%20have%20said
# that%20sapru%20was%20being%20financed%20by%20indian%20pharma%20companies.%20sapru%20filed%20a
# defamation%20suit%20for%20half%20a%20million%20dollars.%20vasella%20eventually%20claimed
# that%20he%20never%20made%20the%20statements.%20it%20is%20also%20said%20that%20sapru%20is%20angry
# because%20novartis%20did%20not%20choose%20cpaa%20to%20run%20its%20free%20treatment%20programme
# but%20instead%20chose%20an%20international%20cancer%20charity%20organisation%20called
# max%20foundation.
#
# %22it's%20true%20that%20we%20were%20in%20talks%20with%20novartis%20and%20things%20didn't%20work
# out%20between%20us,%20but%20that's%20all%20there%20is%20to%20it,%22sapru%20says.%20he%20accuses
# novartis%20of%20using%20max%20foundation,%20%22to%20promote%20both%20glivec%20and%20to%20collect
# clinical%20trial%20data.%20this%20has%20been%20confirmed%20by%20the%20founder%20of%20max
# foundation,%20pedro%20rivarola.%22rivarola's%20son,%20max%20had%20died%20of%20cancer%20and
# so%20he%20was%20emotionally%20involved%20in%20the%20charity.
#
# a%20letter%20written%20by%20rivarola%20to%20sapru%20is%20part%20of%20the%20legal%20documents%20in
# the%20glivec%20case.%20rivarola%20says%20in%20the%20letter,%20%22i%20believed%20(being%20truly
# na?ve)%20in%20the%20good%20will%20of%20novartis%20the%20relationship%20changed%20into%20a
# daily%20struggle%20to%20keep%20my%20beloved%20foundation%20independent%20from%20novartis'
# insatiable%20pawsthe%20last%20drop%20in%20the%20goblet%20made%20me%20leave.%20it%20was%20the
# situation%20in%20thailand%20where%20novartis%20demanded%20that%20patients%20had%20to%20buy
# three%20months%20of%20supply%20before%20qualifying%20for%20the%20program;%20it's%20time%20to
# stop%20this%20as%20the%20name%20of%20my%20son%20is%20being%20trashed%20and%20abused%20just%20for
# marketing%20reasons.%22
#
# the%20battle%20beween%20cpaa%20and%20novartis%20also%20has%20racial%20overtones.%20it%20is
# being%20unofficially%20viewed%20as%20mnc%20vs%20india.%20anand%20grover,%20a%20lawyer
# representing%20cpaa%20against%20novartis%20says,%20%22it's%20time%20the%20whites%20know%20that
# they%20cannot%20walk%20into%20this%20country%20and%20expect%20us%20to%20be%20intimidated%20as
# before.%20we%20know%20how%20to%20fight.%22he%20is%20optimistic%20that%20the%20future%20of%20indian
# generics%20is%20not%20in%20jeopardy.%20%22but%20don't%20forget,%20they%20too%20are%20in%20it%20for
# the%20money.%22
#
# sapru%20says%20that%20the%20production%20cost%20of%20a%20glivec%20generic%20is%20about%20rs
# 1,000.%20%22indian%20companies%20are%20selling%20it%20at%2010%20times%20the%20price.%20so,%20they
# are%20making%20huge%20profits.%20but,%20at%20least,%20they%20are%20cheaper%20than%20glivec.%22dg
# shah,%20secretary%20general%20of%20the%20indian%20pharmaceutical%20alliance,%20says
# matter-of-factly,%20%22it's%20true,%20we%20are%20not%20here%20for%20charity.%22indian%20pharma
# is%20valued%20at%20over%20$%205%20billion,%2065%25%20of%20this%20coming%20from%20the%20export%20of
# generic%20drugs%20to%20developing.
#
# %22these%20revenues%20will%20help%20us%20invest%20in%20research,%22dg%20shah%20says,%20%22and%20in
# the%20coming%20years,%20india%20will%20be%20known%20as%20not%20just%20the%20maker%20of%20cheap
# copies%20but%20as%20a%20research%20hub%20which%20makes%20its%20own%20blockbuster%20drugs.%22but
# the%20future%20of%20generics%20and%20how%20the%20poor%20will%20buy%20their%20right%20to%20stay
# alive%20is%20still%20not%20clear.
#
# copyright%202007%20the%20times%20of%20india.%20bennett,%20coleman%20&%20co%20ltd.%20source%20:
# financial%20times%20information%20limited
#
# --
# joana%20ramos,%20msw
# cancer%20resources%20&%20advocacy
# seattle%20wa%20usa
# tel.%20+1-206-229-2420
# http://ramoslink.info/
# www.cancersurvivorsproject.org
# www.healthyskepticism.org
#
#
#
# _______________________________________________
# ip-health%20mailing%20list
# ip-health@lists.essential.org
# http://lists.essential.org/mailman/listinfo/ip-health' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/dist-packages/xlsxwriter/worksheet.py:832: UserWarning: Ignoring URL 'http://www.manilatimes.net/national/2007/apr/26/yehey/opinion/
# 20070426opi5.html
#
# thursday,%20april%2026,%202007
#
# virtual%20reality
# by%20tony%20lopez
# novartis%20sues%20india%20on%20patents
#
# the%20giant%20swiss%20drug%20multinational%20novartis%20challenge%20to%20indias
# patent%20laws%20could%20seriously%20reduce,%20if%20not%20cut%20the%20supply%20of%20affordable
# medicines%20to%20treat%20aids%20and%20other%20epidemics%20in%20poor%20countries.
#
# india%20changed%20its%20patent%20laws%20in%202005%20to%20comply%20with%20a%20global%20agreement
# on%20intellectual%20property.%20subsequently,%20novar­tis%20applied%20for%20a%20patent.
# it%20is%20one%20of%20the%20first%20under%20the%20new%20rules.%20it%20is%20for%20its%20leukemia
# anticancer%20drug%20glivec.
#
# in%20january%202006%20indias%20patent%20office%20rejected%20the%20application.
# novartis%20protested%20and%20sued%20in%20court.%20it%20is%20also%20challenging%20indias
# patent%20laws,%20claiming%20that%20they%20do%20not%20comply%20with%20the%20international
# agreement.
#
# the%20trial%20opened%20in%20madras.%20the%20main%20issue%20is%20the%20question%20of
# innovation.%20indias%20patent%20law%20requires%20that%20drugs%20be%20new%20and%20involve
# an%20inventive%20step%20in%20order%20to%20win%20patent%20protection.
#
# ngos%20including%20medécins%20sans%20frontiéres%20(msf)%20and%20oxfam%20say%20that%20if
# novartis%20succeeds,%20pharmaceutical%20firms%20will%20be%20able%20to%20put%20newer%20aids
# treatments%20based%20on%20existing%20drugs%20under%20patent%20protection%20in%20india,
# preventing%20cheap%20generic%20versions%20being%20exported%20to%20africa%20and
# elsewhere.
#
# india%20became%20the%20pharmacy%20of%20the%20worlds%20poor%20in%201970%20when%20it%20stopped
# issuing%20drug%20patents,%20allowing%20its%20many%20drug%20producers%20to%20create
# generic%20copies%20of%20medicines%20still%20patent-protected%20in%20other
# countriesat%20a%20fraction%20of%20the%20price%20charged%20by%20multinational%20drug
# behemoths.%20in%201994,%20however,%20new%20delhi%20became%20signatory%20to%20the
# agreement%20on%20trade%20related%20aspects%20of%20intellectual%20property%20rights
# (trips),%20a%20deal%20which%20required%20all%20wto%20member%20countries%20to%20grant
# patents%20on%20technological%20products,%20including%20pharmaceuticals,%20by%202005.
#
# this%20prompted%20drug%20firms%20to%20queue%20up%20to%20patent%20their%20brands%20in%20india.
# up%20to%209,000%20patents%20await%20examination.%20glivec%20was%20one%20of%20the%20first%20to
# go%20to%20court.
#
# novartis%20bid%20was%20rejected%20because%20it%20was%20judged%20to%20be%20merely%20a%20new
# version%20of%20an%20older%20medicine.%20the%20swiss%20company%20argues%20that%20indias
# requirement%20for%20drugs%20to%20be%20new%20and%20innovative%20is%20not%20in%20line%20with%20the
# trips.
#
# %20%20it%20is%20not%20clear%20whether%20the%20glivec%20case%20would%20set%20a%20precedent%20allowing
# other%20modified%20drugs%20to%20be%20patented%20in%20india.%20there%20are%20an%20estimated
# 9,000%20patent%20applications%20waiting%20to%20be%20reviewed,%20of%20which%20some%207,000
# are%20said%20to%20be%20modifications%20of%20old%20drugs,%20says%20richard%20english,
# manager%20of%20oxfams%20make%20trade%20fair%20campaign.%20if%20novartis%20wins,
# countless%20medicines%20previously%20available%20cheaply%20to%20poor%20people%20could
# then%20be%20patented%20and%20priced%20out%20of%20reach.
#
# while%20the%20company%20sells%20the%20drug%20at%20a%20price%20of%20rs%201,200,000,%20indian
# companies%20retail%20it%20at%20rs%208,000.%20ngos%20say%20the%20outcome%20of%20the%20case%20could
# have%20a%20profound%20effect%20on%20the%20accessibility%20to%20generic%20medicines%20in%20the
# developing%20world.
#
# glivec%20is%20considered%20a%20breakthrough%20therapy%20for%20treating%20chronic
# myeloid%20leukemia.
#
# in%20challenging%20the%20indian%20patent%20law,%20novartis%20in%20effect%20is%20saying%20any
# variation%20of%20an%20existing%20drug%20is%20patentable.%20also%20patentable%20will%20be
# new%20uses%20of%20existing%20drugs%20or%20even%20new%20combinations%20or%20delivery%20systems
# of%20existing%20drugs%20might%20be%20patentable.
#
# meanwhile,%20medécins%20sans%20frontiéres%20is%20said%20to%20have%20collected%20some
# 300,000%20signatures%20worldwide%20to%20pressure%20novartis%20to%20drop%20its%20case.
#
# msf%20says%20generic%20manufacturers%20have%20helped%20bring%20the%20cost%20of%20aids
# treatment%20down%20from%20$10,000%20per%20patient%20per%20year%20in%202000,%20to%20just%20$130
# now.
#
# the%20glivec%20case%20is%20a%20litmus%20test,%20said%20us%20chamber%20of%20commerces
# senior%20vice%20president%20daniel%20christman.
#
# if%20india%20chooses%20to%20protect%20the%20intellectual%20property%20of%20novartis,%20it
# will%20help%20open%20a%20floodgate%20of%20investment%20into%20indias%20pharmaceutical
# industry,%20propelling%20india%20onto%20center%20stage%20as%20a%20destination%20for
# innovation,%20r%20&%20d,%20and%20breakthrough%20medicine,%20he%20said.
#
# the%20berne%20declaration,%20ox­farm%20international%20and%20the%20international
# medical%20humanitarian%20organization%20medécins%20sans%20frontiéres%20have
# emphasized%20that%20novartis%20is%20challenging%20countries%20rights%20to%20have
# patent%20laws%20that%20put%20the%20interest%20of%20people%20first.
#
# the%20doha%20declaration%20tries%20to%20find%20a%20balance%20between%20intellectual
# property%20rights%20and%20public%20health,%20said%20ruth%20dreifuss,%20who%20chaired%20the
# 2004-06%20who%20commission%20on%20intellectual%20property%20rights,%20innovation%20and
# public%20health%20(cipih).%20the%20balance%20can%20be%20achieved%20only%20of%20countries
# make%20use%20of%20the%20flexibilities%20contained%20in%20the%20trips%20agreement,%20and
# this%20is%20what%20the%20indian%20law%20does.%20by%20challenging%20it,%20novartis%20is
# sacrificing%20public%20health%20objectives%20and%20weakening%20the%20whole%20system.
#
# many%20developing%20countries%20rely%20on%20affordable%20medicines.%20over%20half%20the
# aids%20drugs%20used%20in%20the%20developing%20world%20are%20generics.%20india%20has%20been
# able%20to%20produce%20affordable%20versions%20of%20medicines%20patented%20elsewhere
# because%20until%202005,%20the%20country%20did%20not%20grant%20pharmaceutical%20patents
#
# ---------------------------------
# thiru%20balasubramaniam
# geneva%20representative
# knowledge%20ecology%20international%20(kei)
# voice%20+41.22.791.6727
# fax%20+41.22.723.2988
# mobile%20+41%2076%20508%200997
# thiru@keionline.org
# _______________________________________________
# ip-health%20mailing%20list
# ip-health@lists.essential.org
# http://lists.essential.org/mailman/listinfo/ip-health' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))

# %%
from google.colab import files
files.download('structured.xlsx')
